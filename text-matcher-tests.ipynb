# %%
import json
from collections import Counter
import pandas as pd
from nltk.corpus import names
import nltk
import re 
import os
import difflib 
import logging
import itertools
from nltk.util import ngrams 
from difflib import SequenceMatcher
from string import punctuation
from termcolor import colored
from IPython.display import clear_output
# %matplotlib inline

# %%
logging.basicConfig()
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
with open('txt/e1a.json') as f: 
    rawData = f.read()

df = pd.read_json(rawData)

# %%
test1 = df.loc[0]['ocr']

# %%
tests = df['ocr']

# %%
class Text: 
    def __init__(self, raw_text, label, removeStopwords=True): 
        if type(raw_text) == list: 
            # JSTOR critical works come in lists, where each item represents a page. 
            self.text = ' \n '.join(raw_text)
        else: 
            self.text = raw_text
        self.label = label
        self.tokens = self.getTokens(removeStopwords)
        self.trigrams = self.ngrams(3)
        
    def getTokens(self, removeStopwords=True): 
        """ Tokenizes the text, breaking it up into words, removing punctuation. """
        tokenizer = nltk.RegexpTokenizer('[a-zA-Z]\w+\'?\w*') # A custom regex tokenizer. 
        #tokenizer = nltk.RegexpTokenizer('\w+|\$[\d\.]+|\S+') # A custom regex tokenizer. 
        spans = list(tokenizer.span_tokenize(self.text))
        # Take note of how many spans there are in the text
        #print(spans)
        self.length = spans[-1][-1] 
        tokens = tokenizer.tokenize(self.text)
        tokens = [ token.lower() for token in tokens ] # make them lowercase
        if not removeStopwords: 
            self.spans = spans
            return tokens
        tokenSpans = list(zip(tokens, spans)) # zip it up
        stopwords = nltk.corpus.stopwords.words('english') # get stopwords
        tokenSpans = [ token for token in tokenSpans if token[0] not in stopwords ] # remove stopwords from zip
        self.spans = [ x[1] for x in tokenSpans ] # unzip; get spans
        return [ x[0] for x in tokenSpans ] # unzip; get tokens
    
    def ngrams(self, n): 
        """ Returns ngrams for the text."""
        return list(ngrams(self.tokens, n))

class Matcher: 
    def __init__(self, textObjA, textObjB, threshold=5, ngramSize=3, removeStopwords=True):
        """
        Takes as input two Text() objects, and matches between them.
        """
        self.threshold = threshold
        self.ngramSize = ngramSize
        
        #self.textA, self.textB = Text(fileA, removeStopwords=removeStopwords), \
        #        Text(fileB, removeStopwords=removeStopwords)
        self.textA = textObjA
        self.textB = textObjB 
        
        self.textAgrams = self.textA.ngrams(ngramSize)
        self.textBgrams = self.textB.ngrams(ngramSize)

        self.locationsA = []
        self.locationsB = []

    def getContext(self, text, start, length, context): 
        match = self.getTokensText(text, start, length)
        before = self.getTokensText(text, start-context, context)
        after = self.getTokensText(text, start+length, context)
        match = colored(match, 'red')
        out = " ".join([before, match, after])
        out = out.replace('\n', ' ') # Replace newlines with spaces. 
        out = re.sub('\s+', ' ', out)
        return out

    def getTokensText(self, text, start, length):  
        """ Looks up the passage in the original text, using its spans. """
        matchTokens = text.tokens[start:start+length]
        spans = text.spans[start:start+length]
        if len(spans) == 0: 
            # Don't try to get text or context beyond the end of a text. 
            passage = ""
        else: 
            passage = text.text[spans[0][0]:spans[-1][-1]]
        return passage 

    def getLocations(self, text, start, length, asPercentages=False): 
        """ Gets the numeric locations of the match. """
        spans = text.spans[start:start+length]
        if asPercentages: 
            locations = (spans[0][0]/text.length, spans[-1][-1]/text.length)
        else: 
            locations = (spans[0][0], spans[-1][-1])
        return locations

    def getMatch(self, match, textA, textB, context): 
        length = match.size + self.ngramSize - 1 # offset according to nGram size 
        wordsA = self.getContext(textA, match.a, length, context)
        wordsB = self.getContext(textB, match.b, length, context)
        spansA = self.getLocations(textA, match.a, length)
        spansB = self.getLocations(textB, match.b, length)
        self.locationsA.append(spansA)
        self.locationsB.append(spansB)
        line1 = ('%s: %s %s' % (colored(textA.label, 'green'), spansA, wordsA) )
        line2 = ('%s: %s %s' % (colored(textB.label, 'green'), spansB, wordsB) )
        return line1 + '\n' + line2

    def match(self): 
        """
        This does the main work of finding matching n-gram sequences between
        the texts.
        """
        sequence = SequenceMatcher(None,self.textAgrams,self.textBgrams)
        matchingBlocks = sequence.get_matching_blocks()

        # Only return the matching sequences that are higher than the 
        # threshold given by the user. 
        highMatchingBlocks = [match for match in matchingBlocks if match.size > self.threshold]
    
        numBlocks = len(highMatchingBlocks)
        self.numMatches = numBlocks
        
        if numBlocks > 0: 
            print('%s total matches found.' % numBlocks, flush=True)

        for num, match in enumerate(highMatchingBlocks): 
            print('match: ', match)
            out = self.getMatch(match, self.textA, self.textB, 5)
            print('\n')
            print('match %s:' % (num+1), flush=True)
            print(out, flush=True)

        return self.numMatches, self.locationsA, self.locationsB

# %%
test1Text = Text(test1, 'test1')

# %%
mm = Text(open('middlemarch.txt').read(), 'Middlemarch')

# %%
class Match(): 
    """ Replacement for SequenceMatcher that does fuzzy text matching."""
    def __init__(self, textAgrams, textBgrams): 
        self.textAgrams = textAgrams
        self.textBgrams = textBgrams
    
    @property
    def initialMatches(self): 
        matches = set(self.textAgrams).intersection(self.textBgrams)
        return list(matches)
    
    @property
    def extendedMatches(self): 
        extendedMatches = []
        for match in self.initialMatches: 
            # Extend the match as far as possible exactly, first.
            match = self.extendedExactMatch(match)
                
            # Now extend the match as far as possible fuzzily. 
            match = self.extendedFuzzyMatch(match)
            
            extendedMatches.append(match)
        return extendedMatches
    
    def extendedExactMatch(self, match): 
        extended = [match]
        print(match)
        aLocation = self.textAgrams.index(match)
        bLocation = self.textBgrams.index(match)
        print('aLocation: ', aLocation)
        print('bLocation: ', bLocation)
        go = True
        pi, ni = 1, 1
        counter = 0
        while go: 
            prevA = self.textAgrams[aLocation-pi]
            prevB = self.textBgrams[bLocation-pi]
            nextA = self.textAgrams[aLocation+ni]
            nextB = self.textBgrams[bLocation+ni]
            print('prevA: ', prevA)
            print('prevB: ', prevB)
            print('nextA: ', nextA)
            print('nextB: ', nextB)
            if prevA == prevB: 
                print('prevA is same as prev B')
                extended = [prevA] + extended 
                pi += 1
            elif nextA == nextB:
                print('next A is same as next B')
                extended = extended + [nextA]
                ni += 1
            else: 
                go = False   
            counter += 1 
            if counter > 15: 
                go = False
        return extended
        
    def extendedFuzzyMatch(self, match): 
        pass

# %%
Match(test1Text.trigrams, mm.trigrams).extendedMatches
# Out:
# ('reason', 'think', 'asks')
# aLocation:  1710
# bLocation:  14753
# prevA:  ('chief', 'reason', 'think')
# prevB:  ('chief', 'reason', 'think')
# nextA:  ('think', 'asks', 'large')
# nextB:  ('think', 'asks', 'large')
# prevA is same as prev B
# prevA:  ('eyes', 'chief', 'reason')
# prevB:  ('eyes', 'chief', 'reason')
# nextA:  ('think', 'asks', 'large')
# nextB:  ('think', 'asks', 'large')
# prevA is same as prev B
# prevA:  ('important', 'eyes', 'chief')
# prevB:  ('important', 'eyes', 'chief')
# nextA:  ('think', 'asks', 'large')
# nextB:  ('think', 'asks', 'large')
# prevA is same as prev B
# prevA:  ('lot', 'important', 'eyes')
# prevB:  ('lot', 'important', 'eyes')
# nextA:  ('think', 'asks', 'large')
# nextB:  ('think', 'asks', 'large')
# prevA is same as prev B
# prevA:  ('less', 'lot', 'important')
# prevB:  ('doubtless', 'lot', 'important')
# nextA:  ('think', 'asks', 'large')
# nextB:  ('think', 'asks', 'large')
# next A is same as next B
# prevA:  ('less', 'lot', 'important')
# prevB:  ('doubtless', 'lot', 'important')
# nextA:  ('asks', 'large', 'place')
# nextB:  ('asks', 'large', 'place')
# next A is same as next B
# prevA:  ('less', 'lot', 'important')
# prevB:  ('doubtless', 'lot', 'important')
# nextA:  ('large', 'place', 'consideration')
# nextB:  ('large', 'place', 'consideration')
# next A is same as next B
# prevA:  ('less', 'lot', 'important')
# prevB:  ('doubtless', 'lot', 'important')
# nextA:  ('place', 'consideration', 'must')
# nextB:  ('place', 'consideration', 'must')
# next A is same as next B
# prevA:  ('less', 'lot', 'important')
# prevB:  ('doubtless', 'lot', 'important')
# nextA:  ('consideration', 'must', 'want')
# nextB:  ('consideration', 'must', 'want')
# next A is same as next B
# prevA:  ('less', 'lot', 'important')
# prevB:  ('doubtless', 'lot', 'important')
# nextA:  ('must', 'want', 'room')
# nextB:  ('must', 'want', 'room')
# next A is same as next B
# prevA:  ('less', 'lot', 'important')
# prevB:  ('doubtless', 'lot', 'important')
# nextA:  ('want', 'room', 'mr')
# nextB:  ('want', 'room', 'since')
# ('presentiment', 'might', 'sad')
# aLocation:  3679
# bLocation:  38435
# prevA:  ('waking', 'presentiment', 'might')
# prevB:  ('waking', 'presentiment', 'might')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('felt', 'waking', 'presentiment')
# prevB:  ('felt', 'waking', 'presentiment')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('casaubon', 'felt', 'waking')
# prevB:  ('casaubon', 'felt', 'waking')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('mr', 'casaubon', 'felt')
# prevB:  ('mr', 'casaubon', 'felt')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('feeling', 'mr', 'casaubon')
# prevB:  ('feeling', 'mr', 'casaubon')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('response', 'feeling', 'mr')
# prevB:  ('response', 'feeling', 'mr')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('expecting', 'response', 'feeling')
# prevB:  ('expecting', 'response', 'feeling')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('illusion', 'expecting', 'response')
# prevB:  ('illusion', 'expecting', 'response')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('wild', 'illusion', 'expecting')
# prevB:  ('wild', 'illusion', 'expecting')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('see', 'wild', 'illusion')
# prevB:  ('see', 'wild', 'illusion')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('begun', 'see', 'wild')
# prevB:  ('begun', 'see', 'wild')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# prevA is same as prev B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('sad', 'consciousness', 'life')
# nextB:  ('sad', 'consciousness', 'life')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('consciousness', 'life', 'made')
# nextB:  ('consciousness', 'life', 'made')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('life', 'made', 'great')
# nextB:  ('life', 'made', 'great')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('made', 'great', 'need')
# nextB:  ('made', 'great', 'need')
# next A is same as next B
# ('america', 'spirited', 'young')
# aLocation:  2077
# bLocation:  26428
# prevA:  ('fine', 'america', 'spirited')
# prevB:  ('fine', 'america', 'spirited')
# nextA:  ('spirited', 'young', 'adventurer')
# nextB:  ('spirited', 'young', 'adventurer')
# prevA is same as prev B
# prevA:  ('pathology', 'fine', 'america')
# prevB:  ('pathology', 'fine', 'america')
# nextA:  ('spirited', 'young', 'adventurer')
# nextB:  ('spirited', 'young', 'adventurer')
# prevA is same as prev B
# prevA:  ('territories', 'pathology', 'fine')
# prevB:  ('territories', 'pathology', 'fine')
# nextA:  ('spirited', 'young', 'adventurer')
# nextB:  ('spirited', 'young', 'adventurer')
# prevA is same as prev B
# prevA:  ('dark', 'territories', 'pathology')
# prevB:  ('dark', 'territories', 'pathology')
# nextA:  ('spirited', 'young', 'adventurer')
# nextB:  ('spirited', 'young', 'adventurer')
# prevA is same as prev B
# prevA:  ('lydgate', 'dark', 'territories')
# prevB:  ('kingdom', 'dark', 'territories')
# nextA:  ('spirited', 'young', 'adventurer')
# nextB:  ('spirited', 'young', 'adventurer')
# next A is same as next B
# prevA:  ('lydgate', 'dark', 'territories')
# prevB:  ('kingdom', 'dark', 'territories')
# nextA:  ('young', 'adventurer', 'episode')
# nextB:  ('young', 'adventurer', 'lydgate')
# ('bear', 'much', 'keen')
# aLocation:  3627
# bLocation:  35394
# prevA:  ('hardly', 'bear', 'much')
# prevB:  ('hardly', 'bear', 'much')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('could', 'hardly', 'bear')
# prevB:  ('could', 'hardly', 'bear')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('frames', 'could', 'hardly')
# prevB:  ('frames', 'could', 'hardly')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('perhaps', 'frames', 'could')
# prevB:  ('perhaps', 'frames', 'could')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('mankind', 'perhaps', 'frames')
# prevB:  ('mankind', 'perhaps', 'frames')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('emotion', 'mankind', 'perhaps')
# prevB:  ('emotion', 'mankind', 'perhaps')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('coarse', 'emotion', 'mankind')
# prevB:  ('coarse', 'emotion', 'mankind')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('wrought', 'coarse', 'emotion')
# prevB:  ('wrought', 'coarse', 'emotion')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('yet', 'wrought', 'coarse')
# prevB:  ('yet', 'wrought', 'coarse')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('frequency', 'yet', 'wrought')
# prevB:  ('frequency', 'yet', 'wrought')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('fact', 'frequency', 'yet')
# prevB:  ('fact', 'frequency', 'yet')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('lies', 'fact', 'frequency')
# prevB:  ('lies', 'fact', 'frequency')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('tragedy', 'lies', 'fact')
# prevB:  ('tragedy', 'lies', 'fact')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('element', 'tragedy', 'lies')
# prevB:  ('element', 'tragedy', 'lies')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# prevA is same as prev B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('keen', 'vision', 'feeling')
# nextB:  ('keen', 'vision', 'feeling')
# next A is same as next B
# ('take', 'strictly', 'scientific')
# aLocation:  2110
# bLocation:  27633
# prevA:  ('would', 'take', 'strictly')
# prevB:  ('would', 'take', 'strictly')
# nextA:  ('strictly', 'scientific', 'view')
# nextB:  ('strictly', 'scientific', 'view')
# prevA is same as prev B
# prevA:  ('henceforth', 'would', 'take')
# prevB:  ('henceforth', 'would', 'take')
# nextA:  ('strictly', 'scientific', 'view')
# nextB:  ('strictly', 'scientific', 'view')
# prevA is same as prev B
# prevA:  ('middlemarch', 'henceforth', 'would')
# prevB:  ('experienced', 'henceforth', 'would')
# nextA:  ('strictly', 'scientific', 'view')
# nextB:  ('strictly', 'scientific', 'view')
# next A is same as next B
# prevA:  ('middlemarch', 'henceforth', 'would')
# prevB:  ('experienced', 'henceforth', 'would')
# nextA:  ('scientific', 'view', 'woman')
# nextB:  ('scientific', 'view', 'woman')
# next A is same as next B
# prevA:  ('middlemarch', 'henceforth', 'would')
# prevB:  ('experienced', 'henceforth', 'would')
# nextA:  ('view', 'woman', "lydgate's")
# nextB:  ('view', 'woman', 'entertaining')
# ('lived', 'faithfully', 'hidden')
# aLocation:  4297
# bLocation:  152481
# prevA:  ('number', 'lived', 'faithfully')
# prevB:  ('number', 'lived', 'faithfully')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('owing', 'number', 'lived')
# prevB:  ('owing', 'number', 'lived')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('half', 'owing', 'number')
# prevB:  ('half', 'owing', 'number')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('might', 'half', 'owing')
# prevB:  ('might', 'half', 'owing')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('ill', 'might', 'half')
# prevB:  ('ill', 'might', 'half')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('things', 'ill', 'might')
# prevB:  ('things', 'ill', 'might')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('acts', 'things', 'ill')
# prevB:  ('acts', 'things', 'ill')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('unhistoric', 'acts', 'things')
# prevB:  ('unhistoric', 'acts', 'things')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('dependent', 'unhistoric', 'acts')
# prevB:  ('dependent', 'unhistoric', 'acts')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('partly', 'dependent', 'unhistoric')
# prevB:  ('partly', 'dependent', 'unhistoric')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('world', 'partly', 'dependent')
# prevB:  ('world', 'partly', 'dependent')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('good', 'world', 'partly')
# prevB:  ('good', 'world', 'partly')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('growing', 'good', 'world')
# prevB:  ('growing', 'good', 'world')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('diffusive', 'growing', 'good')
# prevB:  ('diffusive', 'growing', 'good')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('incalculably', 'diffusive', 'growing')
# prevB:  ('incalculably', 'diffusive', 'growing')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# prevA:  ('around', 'incalculably', 'diffusive')
# prevB:  ('around', 'incalculably', 'diffusive')
# nextA:  ('faithfully', 'hidden', 'life')
# nextB:  ('faithfully', 'hidden', 'life')
# prevA is same as prev B
# ('development', 'varies', 'sometimes')
# aLocation:  2135
# bLocation:  25789
# prevA:  ('passion', 'development', 'varies')
# prevB:  ('passion', 'development', 'varies')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('story', 'passion', 'development')
# prevB:  ('story', 'passion', 'development')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('desires', 'story', 'passion')
# prevB:  ('desires', 'story', 'passion')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('small', 'desires', 'story')
# prevB:  ('small', 'desires', 'story')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('renunciation', 'small', 'desires')
# prevB:  ('renunciation', 'small', 'desires')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('patient', 'renunciation', 'small')
# prevB:  ('patient', 'renunciation', 'small')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('thought', 'patient', 'renunciation')
# prevB:  ('thought', 'patient', 'renunciation')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('industrious', 'thought', 'patient')
# prevB:  ('industrious', 'thought', 'patient')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('wooed', 'industrious', 'thought')
# prevB:  ('wooed', 'industrious', 'thought')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('must', 'wooed', 'industrious')
# prevB:  ('must', 'wooed', 'industrious')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('fairnesse', 'must', 'wooed')
# prevB:  ('fairnesse', 'must', 'wooed')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('makdom', 'fairnesse', 'must')
# prevB:  ('makdom', 'fairnesse', 'must')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('kind', 'makdom', 'fairnesse')
# prevB:  ('kind', 'makdom', 'fairnesse')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# prevA is same as prev B
# prevA:  ('vocation', 'kind', 'makdom')
# prevB:  ('uninterested', 'kind', 'makdom')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# next A is same as next B
# prevA:  ('vocation', 'kind', 'makdom')
# prevB:  ('uninterested', 'kind', 'makdom')
# nextA:  ('sometimes', 'glorious', 'marriage')
# nextB:  ('sometimes', 'glorious', 'marriage')
# next A is same as next B
# prevA:  ('vocation', 'kind', 'makdom')
# prevB:  ('uninterested', 'kind', 'makdom')
# nextA:  ('glorious', 'marriage', 'sometimes')
# nextB:  ('glorious', 'marriage', 'sometimes')
# next A is same as next B
# ('another', 'tells', 'like')
# aLocation:  3089
# bLocation:  16794
# prevA:  ('life', 'another', 'tells')
# prevB:  ('life', 'another', 'tells')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('one', 'life', 'another')
# prevB:  ('one', 'life', 'another')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('effects', 'one', 'life')
# prevB:  ('effects', 'one', 'life')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('preparation', 'effects', 'one')
# prevB:  ('preparation', 'effects', 'one')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('slow', 'preparation', 'effects')
# prevB:  ('slow', 'preparation', 'effects')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('sees', 'slow', 'preparation')
# prevB:  ('sees', 'slow', 'preparation')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('lots', 'sees', 'slow')
# prevB:  ('lots', 'sees', 'slow')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('human', 'lots', 'sees')
# prevB:  ('human', 'lots', 'sees')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('convergence', 'human', 'lots')
# prevB:  ('convergence', 'human', 'lots')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('stealthy', 'convergence', 'human')
# prevB:  ('stealthy', 'convergence', 'human')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('keenly', 'stealthy', 'convergence')
# prevB:  ('keenly', 'stealthy', 'convergence')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('watching', 'keenly', 'stealthy')
# prevB:  ('watching', 'keenly', 'stealthy')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('one', 'watching', 'keenly')
# prevB:  ('one', 'watching', 'keenly')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('surgeon', 'one', 'watching')
# prevB:  ('surgeon', 'one', 'watching')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('young', 'surgeon', 'one')
# prevB:  ('young', 'surgeon', 'one')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# prevA:  ('attracted', 'young', 'surgeon')
# prevB:  ('attracted', 'young', 'surgeon')
# nextA:  ('tells', 'like', 'calculated')
# nextB:  ('tells', 'like', 'calculated')
# prevA is same as prev B
# ('distinctness', 'longer', 'reflection')
# aLocation:  3716
# bLocation:  38472
# prevA:  ('conceive', 'distinctness', 'longer')
# prevB:  ('conceive', 'distinctness', 'longer')
# nextA:  ('longer', 'reflection', 'feeling')
# nextB:  ('longer', 'reflection', 'feeling')
# prevA is same as prev B
# prevA:  ('wisdom', 'conceive', 'distinctness')
# prevB:  ('wisdom', 'conceive', 'distinctness')
# nextA:  ('longer', 'reflection', 'feeling')
# nextB:  ('longer', 'reflection', 'feeling')
# prevA is same as prev B
# prevA:  ('strength', 'wisdom', 'conceive')
# prevB:  ('strength', 'wisdom', 'conceive')
# nextA:  ('longer', 'reflection', 'feeling')
# nextB:  ('longer', 'reflection', 'feeling')
# prevA is same as prev B
# prevA:  ('strong', 'strength', 'wisdom')
# prevB:  ('strong', 'strength', 'wisdom')
# nextA:  ('longer', 'reflection', 'feeling')
# nextB:  ('longer', 'reflection', 'feeling')
# prevA is same as prev B
# prevA:  ('wise', 'strong', 'strength')
# prevB:  ('wise', 'strong', 'strength')
# nextA:  ('longer', 'reflection', 'feeling')
# nextB:  ('longer', 'reflection', 'feeling')
# prevA is same as prev B
# prevA:  ('come', 'wise', 'strong')
# prevB:  ('become', 'wise', 'strong')
# nextA:  ('longer', 'reflection', 'feeling')
# nextB:  ('longer', 'reflection', 'feeling')
# next A is same as next B
# prevA:  ('come', 'wise', 'strong')
# prevB:  ('become', 'wise', 'strong')
# nextA:  ('reflection', 'feeling', 'equivalent')
# nextB:  ('reflection', 'feeling', 'idea')
# ('silence', 'quickest', 'us')
# aLocation:  3647
# bLocation:  35414
# prevA:  ('side', 'silence', 'quickest')
# prevB:  ('side', 'silence', 'quickest')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('lies', 'side', 'silence')
# prevB:  ('lies', 'side', 'silence')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('roar', 'lies', 'side')
# prevB:  ('roar', 'lies', 'side')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('die', 'roar', 'lies')
# prevB:  ('die', 'roar', 'lies')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('beat', 'die', 'roar')
# prevB:  ('beat', 'die', 'roar')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('heart', 'beat', 'die')
# prevB:  ('heart', 'beat', 'die')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ("squirrel's", 'heart', 'beat')
# prevB:  ("squirrel's", 'heart', 'beat')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('grow', "squirrel's", 'heart')
# prevB:  ('grow', "squirrel's", 'heart')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('grass', 'grow', "squirrel's")
# prevB:  ('grass', 'grow', "squirrel's")
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('hearing', 'grass', 'grow')
# prevB:  ('hearing', 'grass', 'grow')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('like', 'hearing', 'grass')
# prevB:  ('like', 'hearing', 'grass')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('would', 'like', 'hearing')
# prevB:  ('would', 'like', 'hearing')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('life', 'would', 'like')
# prevB:  ('life', 'would', 'like')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('human', 'life', 'would')
# prevB:  ('human', 'life', 'would')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('ordinary', 'human', 'life')
# prevB:  ('ordinary', 'human', 'life')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# prevA:  ('feeling', 'ordinary', 'human')
# prevB:  ('feeling', 'ordinary', 'human')
# nextA:  ('quickest', 'us', 'walk')
# nextB:  ('quickest', 'us', 'walk')
# prevA is same as prev B
# ('miss', 'brooke', 'mr')
# aLocation:  2730
# bLocation:  16489
# prevA:  ('career', 'miss', 'brooke')
# prevB:  ('evidently', 'miss', 'brooke')
# nextA:  ('brooke', 'mr', "garth's")
# nextB:  ('brooke', 'mr', "lydgate's")
# ('make', 'vortices', 'victims')
# aLocation:  2565
# bLocation:  10117
# prevA:  ('hairlets', 'make', 'vortices')
# prevB:  ('hairlets', 'make', 'vortices')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('tiniest', 'hairlets', 'make')
# prevB:  ('tiniest', 'hairlets', 'make')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('certain', 'tiniest', 'hairlets')
# prevB:  ('certain', 'tiniest', 'hairlets')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('reveals', 'certain', 'tiniest')
# prevB:  ('reveals', 'certain', 'tiniest')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('lens', 'reveals', 'certain')
# prevB:  ('lens', 'reveals', 'certain')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('stronger', 'lens', 'reveals')
# prevB:  ('stronger', 'lens', 'reveals')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('pennies', 'stronger', 'lens')
# prevB:  ('pennies', 'stronger', 'lens')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('tax', 'pennies', 'stronger')
# prevB:  ('tax', 'pennies', 'stronger')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('animated', 'tax', 'pennies')
# prevB:  ('animated', 'tax', 'pennies')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('many', 'animated', 'tax')
# prevB:  ('many', 'animated', 'tax')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('play', 'many', 'animated')
# prevB:  ('play', 'many', 'animated')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# prevA is same as prev B
# prevA:  ('tively', 'play', 'many')
# prevB:  ('actively', 'play', 'many')
# nextA:  ('vortices', 'victims', 'swallower')
# nextB:  ('vortices', 'victims', 'swallower')
# next A is same as next B
# prevA:  ('tively', 'play', 'many')
# prevB:  ('actively', 'play', 'many')
# nextA:  ('victims', 'swallower', 'waits')
# nextB:  ('victims', 'swallower', 'waits')
# next A is same as next B
# prevA:  ('tively', 'play', 'many')
# prevB:  ('actively', 'play', 'many')
# nextA:  ('swallower', 'waits', 'passively')
# nextB:  ('swallower', 'waits', 'passively')
# next A is same as next B
# prevA:  ('tively', 'play', 'many')
# prevB:  ('actively', 'play', 'many')
# nextA:  ('waits', 'passively', 'receipt')
# nextB:  ('waits', 'passively', 'receipt')
# next A is same as next B
# prevA:  ('tively', 'play', 'many')
# prevB:  ('actively', 'play', 'many')
# nextA:  ('passively', 'receipt', 'custom')
# nextB:  ('passively', 'receipt', 'custom')
# next A is same as next B
# ('social', 'lot', 'women')
# aLocation:  2441
# bLocation:  217
# prevA:  ('brooke', 'social', 'lot')
# prevB:  ('three', 'social', 'lot')
# nextA:  ('lot', 'women', 'might')
# nextB:  ('lot', 'women', 'might')
# next A is same as next B
# prevA:  ('brooke', 'social', 'lot')
# prevB:  ('three', 'social', 'lot')
# nextA:  ('women', 'might', 'treated')
# nextB:  ('women', 'might', 'treated')
# next A is same as next B
# prevA:  ('brooke', 'social', 'lot')
# prevB:  ('three', 'social', 'lot')
# nextA:  ('might', 'treated', 'scientific')
# nextB:  ('might', 'treated', 'scientific')
# next A is same as next B
# prevA:  ('brooke', 'social', 'lot')
# prevB:  ('three', 'social', 'lot')
# nextA:  ('treated', 'scientific', 'certitude')
# nextB:  ('treated', 'scientific', 'certitude')
# next A is same as next B
# prevA:  ('brooke', 'social', 'lot')
# prevB:  ('three', 'social', 'lot')
# nextA:  ('scientific', 'certitude', 'saint')
# nextB:  ('scientific', 'certitude', 'meanwhile')
# ('frequency', 'yet', 'wrought')
# aLocation:  3617
# bLocation:  35384
# prevA:  ('fact', 'frequency', 'yet')
# prevB:  ('fact', 'frequency', 'yet')
# nextA:  ('yet', 'wrought', 'coarse')
# nextB:  ('yet', 'wrought', 'coarse')
# prevA is same as prev B
# prevA:  ('lies', 'fact', 'frequency')
# prevB:  ('lies', 'fact', 'frequency')
# nextA:  ('yet', 'wrought', 'coarse')
# nextB:  ('yet', 'wrought', 'coarse')
# prevA is same as prev B
# prevA:  ('tragedy', 'lies', 'fact')
# prevB:  ('tragedy', 'lies', 'fact')
# nextA:  ('yet', 'wrought', 'coarse')
# nextB:  ('yet', 'wrought', 'coarse')
# prevA is same as prev B
# prevA:  ('element', 'tragedy', 'lies')
# prevB:  ('element', 'tragedy', 'lies')
# nextA:  ('yet', 'wrought', 'coarse')
# nextB:  ('yet', 'wrought', 'coarse')
# prevA is same as prev B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('yet', 'wrought', 'coarse')
# nextB:  ('yet', 'wrought', 'coarse')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('wrought', 'coarse', 'emotion')
# nextB:  ('wrought', 'coarse', 'emotion')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('coarse', 'emotion', 'mankind')
# nextB:  ('coarse', 'emotion', 'mankind')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('emotion', 'mankind', 'perhaps')
# nextB:  ('emotion', 'mankind', 'perhaps')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('mankind', 'perhaps', 'frames')
# nextB:  ('mankind', 'perhaps', 'frames')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('frames', 'could', 'hardly')
# nextB:  ('frames', 'could', 'hardly')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('could', 'hardly', 'bear')
# nextB:  ('could', 'hardly', 'bear')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('hardly', 'bear', 'much')
# nextB:  ('hardly', 'bear', 'much')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('bear', 'much', 'keen')
# nextB:  ('bear', 'much', 'keen')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('keen', 'vision', 'feeling')
# nextB:  ('keen', 'vision', 'feeling')
# next A is same as next B
# ('neophyte', 'enter', 'higher')
# aLocation:  1212
# bLocation:  7225
# prevA:  ('opening', 'neophyte', 'enter')
# prevB:  ('opening', 'neophyte', 'enter')
# nextA:  ('enter', 'higher', 'grade')
# nextB:  ('enter', 'higher', 'grade')
# prevA is same as prev B
# prevA:  ('life', 'opening', 'neophyte')
# prevB:  ('life', 'opening', 'neophyte')
# nextA:  ('enter', 'higher', 'grade')
# nextB:  ('enter', 'higher', 'grade')
# prevA is same as prev B
# prevA:  ('fuller', 'life', 'opening')
# prevB:  ('fuller', 'life', 'opening')
# nextA:  ('enter', 'higher', 'grade')
# nextB:  ('enter', 'higher', 'grade')
# prevA is same as prev B
# prevA:  ('fact', 'fuller', 'life')
# prevB:  ('fact', 'fuller', 'life')
# nextA:  ('enter', 'higher', 'grade')
# nextB:  ('enter', 'higher', 'grade')
# prevA is same as prev B
# prevA:  ('possessed', 'fact', 'fuller')
# prevB:  ('possessed', 'fact', 'fuller')
# nextA:  ('enter', 'higher', 'grade')
# nextB:  ('enter', 'higher', 'grade')
# prevA is same as prev B
# prevA:  ('soul', 'possessed', 'fact')
# prevB:  ('soul', 'possessed', 'fact')
# nextA:  ('enter', 'higher', 'grade')
# nextB:  ('enter', 'higher', 'grade')
# prevA is same as prev B
# prevA:  ('whole', 'soul', 'possessed')
# prevB:  ('whole', 'soul', 'possessed')
# nextA:  ('enter', 'higher', 'grade')
# nextB:  ('enter', 'higher', 'grade')
# prevA is same as prev B
# prevA:  ('call', 'whole', 'soul')
# prevB:  ('love', 'whole', 'soul')
# nextA:  ('enter', 'higher', 'grade')
# nextB:  ('enter', 'higher', 'grade')
# next A is same as next B
# prevA:  ('call', 'whole', 'soul')
# prevB:  ('love', 'whole', 'soul')
# nextA:  ('higher', 'grade', 'ini')
# nextB:  ('higher', 'grade', 'initiation')
# ('illusion', 'expecting', 'response')
# aLocation:  3671
# bLocation:  38427
# prevA:  ('wild', 'illusion', 'expecting')
# prevB:  ('wild', 'illusion', 'expecting')
# nextA:  ('expecting', 'response', 'feeling')
# nextB:  ('expecting', 'response', 'feeling')
# prevA is same as prev B
# prevA:  ('see', 'wild', 'illusion')
# prevB:  ('see', 'wild', 'illusion')
# nextA:  ('expecting', 'response', 'feeling')
# nextB:  ('expecting', 'response', 'feeling')
# prevA is same as prev B
# prevA:  ('begun', 'see', 'wild')
# prevB:  ('begun', 'see', 'wild')
# nextA:  ('expecting', 'response', 'feeling')
# nextB:  ('expecting', 'response', 'feeling')
# prevA is same as prev B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('expecting', 'response', 'feeling')
# nextB:  ('expecting', 'response', 'feeling')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('response', 'feeling', 'mr')
# nextB:  ('response', 'feeling', 'mr')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('feeling', 'mr', 'casaubon')
# nextB:  ('feeling', 'mr', 'casaubon')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('mr', 'casaubon', 'felt')
# nextB:  ('mr', 'casaubon', 'felt')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('casaubon', 'felt', 'waking')
# nextB:  ('casaubon', 'felt', 'waking')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('felt', 'waking', 'presentiment')
# nextB:  ('felt', 'waking', 'presentiment')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('waking', 'presentiment', 'might')
# nextB:  ('waking', 'presentiment', 'might')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('presentiment', 'might', 'sad')
# nextB:  ('presentiment', 'might', 'sad')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('might', 'sad', 'consciousness')
# nextB:  ('might', 'sad', 'consciousness')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('sad', 'consciousness', 'life')
# nextB:  ('sad', 'consciousness', 'life')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('consciousness', 'life', 'made')
# nextB:  ('consciousness', 'life', 'made')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('life', 'made', 'great')
# nextB:  ('life', 'made', 'great')
# next A is same as next B
# prevA:  ('day', 'begun', 'see')
# prevB:  ('today', 'begun', 'see')
# nextA:  ('made', 'great', 'need')
# nextB:  ('made', 'great', 'need')
# next A is same as next B
# ('like', 'seemed', 'hidden')
# aLocation:  4060
# bLocation:  143756
# prevA:  ('union', 'like', 'seemed')
# prevB:  ('union', 'like', 'seemed')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ('marriage', 'union', 'like')
# prevB:  ('marriage', 'union', 'like')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ('young', 'marriage', 'union')
# prevB:  ('young', 'marriage', 'union')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ('lot', 'young', 'marriage')
# prevB:  ('lot', 'young', 'marriage')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ("lydgate's", 'lot', 'young')
# prevB:  ("lydgate's", 'lot', 'young')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ('trials', "lydgate's", 'lot')
# prevB:  ('trials', "lydgate's", 'lot')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ('representing', 'trials', "lydgate's")
# prevB:  ('representing', 'trials', "lydgate's")
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ('thought', 'representing', 'trials')
# prevB:  ('thought', 'representing', 'trials')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ('active', 'thought', 'representing')
# prevB:  ('active', 'thought', 'representing')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# prevA is same as prev B
# prevA:  ('meaning', 'active', 'thought')
# prevB:  ('things', 'active', 'thought')
# nextA:  ('seemed', 'hidden', 'well')
# nextB:  ('seemed', 'hidden', 'well')
# next A is same as next B
# prevA:  ('meaning', 'active', 'thought')
# prevB:  ('things', 'active', 'thought')
# nextA:  ('hidden', 'well', 'evident')
# nextB:  ('hidden', 'well', 'evident')
# next A is same as next B
# prevA:  ('meaning', 'active', 'thought')
# prevB:  ('things', 'active', 'thought')
# nextA:  ('well', 'evident', 'troubles')
# nextB:  ('well', 'evident', 'troubles')
# next A is same as next B
# prevA:  ('meaning', 'active', 'thought')
# prevB:  ('things', 'active', 'thought')
# nextA:  ('evident', 'troubles', 'vivid')
# nextB:  ('evident', 'troubles', 'vivid')
# next A is same as next B
# prevA:  ('meaning', 'active', 'thought')
# prevB:  ('things', 'active', 'thought')
# nextA:  ('troubles', 'vivid', 'sympathetic')
# nextB:  ('troubles', 'vivid', 'sympathetic')
# next A is same as next B
# prevA:  ('meaning', 'active', 'thought')
# prevB:  ('things', 'active', 'thought')
# nextA:  ('vivid', 'sympathetic', 'ex')
# nextB:  ('vivid', 'sympathetic', 'experience')
# ('partly', 'dependent', 'unhistoric')
# aLocation:  4287
# bLocation:  152471
# prevA:  ('world', 'partly', 'dependent')
# prevB:  ('world', 'partly', 'dependent')
# nextA:  ('dependent', 'unhistoric', 'acts')
# nextB:  ('dependent', 'unhistoric', 'acts')
# prevA is same as prev B
# prevA:  ('good', 'world', 'partly')
# prevB:  ('good', 'world', 'partly')
# nextA:  ('dependent', 'unhistoric', 'acts')
# nextB:  ('dependent', 'unhistoric', 'acts')
# prevA is same as prev B
# prevA:  ('growing', 'good', 'world')
# prevB:  ('growing', 'good', 'world')
# nextA:  ('dependent', 'unhistoric', 'acts')
# nextB:  ('dependent', 'unhistoric', 'acts')
# prevA is same as prev B
# prevA:  ('diffusive', 'growing', 'good')
# prevB:  ('diffusive', 'growing', 'good')
# nextA:  ('dependent', 'unhistoric', 'acts')
# nextB:  ('dependent', 'unhistoric', 'acts')
# prevA is same as prev B
# prevA:  ('incalculably', 'diffusive', 'growing')
# prevB:  ('incalculably', 'diffusive', 'growing')
# nextA:  ('dependent', 'unhistoric', 'acts')
# nextB:  ('dependent', 'unhistoric', 'acts')
# prevA is same as prev B
# prevA:  ('around', 'incalculably', 'diffusive')
# prevB:  ('around', 'incalculably', 'diffusive')
# nextA:  ('dependent', 'unhistoric', 'acts')
# nextB:  ('dependent', 'unhistoric', 'acts')
# prevA is same as prev B
# prevA:  ('effect', 'around', 'incalculably')
# prevB:  ('effect', 'around', 'incalculably')
# nextA:  ('dependent', 'unhistoric', 'acts')
# nextB:  ('dependent', 'unhistoric', 'acts')
# prevA is same as prev B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('dependent', 'unhistoric', 'acts')
# nextB:  ('dependent', 'unhistoric', 'acts')
# next A is same as next B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('unhistoric', 'acts', 'things')
# nextB:  ('unhistoric', 'acts', 'things')
# next A is same as next B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('acts', 'things', 'ill')
# nextB:  ('acts', 'things', 'ill')
# next A is same as next B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('things', 'ill', 'might')
# nextB:  ('things', 'ill', 'might')
# next A is same as next B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('ill', 'might', 'half')
# nextB:  ('ill', 'might', 'half')
# next A is same as next B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('might', 'half', 'owing')
# nextB:  ('might', 'half', 'owing')
# next A is same as next B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('half', 'owing', 'number')
# nextB:  ('half', 'owing', 'number')
# next A is same as next B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('owing', 'number', 'lived')
# nextB:  ('owing', 'number', 'lived')
# next A is same as next B
# prevA:  ("dorothea's", 'effect', 'around')
# prevB:  ('earth', 'effect', 'around')
# nextA:  ('number', 'lived', 'faithfully')
# nextB:  ('number', 'lived', 'faithfully')
# next A is same as next B
# ('ever', 'trusting', 'judgment')
# aLocation:  2089
# bLocation:  27627
# prevA:  ('reason', 'ever', 'trusting')
# prevB:  ('reason', 'ever', 'trusting')
# nextA:  ('trusting', 'judgment', 'experienced')
# nextB:  ('trusting', 'judgment', 'experienced')
# prevA is same as prev B
# prevA:  ('end', 'reason', 'ever')
# prevB:  ('better', 'reason', 'ever')
# nextA:  ('trusting', 'judgment', 'experienced')
# nextB:  ('trusting', 'judgment', 'experienced')
# next A is same as next B
# prevA:  ('end', 'reason', 'ever')
# prevB:  ('better', 'reason', 'ever')
# nextA:  ('judgment', 'experienced', 'middlemarch')
# nextB:  ('judgment', 'experienced', 'henceforth')
# ('else', 'better', 'married')
# aLocation:  4178
# bLocation:  145295
# prevA:  ('someone', 'else', 'better')
# prevB:  ('one', 'else', 'better')
# nextA:  ('better', 'married', 'would')
# nextB:  ('better', 'married', 'would')
# next A is same as next B
# prevA:  ('someone', 'else', 'better')
# prevB:  ('one', 'else', 'better')
# nextA:  ('married', 'would', 'use')
# nextB:  ('married', 'would', 'use')
# next A is same as next B
# prevA:  ('someone', 'else', 'better')
# prevB:  ('one', 'else', 'better')
# nextA:  ('would', 'use', 'mean')
# nextB:  ('would', 'use', 'poor')
# ('made', 'curse', 'life')
# aLocation:  4211
# bLocation:  145335
# prevA:  ('helped', 'made', 'curse')
# prevB:  ('helped', 'made', 'curse')
# nextA:  ('curse', 'life', 'pp')
# nextB:  ('curse', 'life', 'voice')
# prevA is same as prev B
# prevA:  ('us', 'helped', 'made')
# prevB:  ('us', 'helped', 'made')
# nextA:  ('curse', 'life', 'pp')
# nextB:  ('curse', 'life', 'voice')
# prevA is same as prev B
# prevA:  ('trusted', 'us', 'helped')
# prevB:  ('trusted', 'us', 'helped')
# nextA:  ('curse', 'life', 'pp')
# nextB:  ('curse', 'life', 'voice')
# prevA is same as prev B
# prevA:  ('loved', 'trusted', 'us')
# prevB:  ('loved', 'trusted', 'us')
# nextA:  ('curse', 'life', 'pp')
# nextB:  ('curse', 'life', 'voice')
# prevA is same as prev B
# prevA:  ('husband', 'loved', 'trusted')
# prevB:  ('husband', 'loved', 'trusted')
# nextA:  ('curse', 'life', 'pp')
# nextB:  ('curse', 'life', 'voice')
# prevA is same as prev B
# prevA:  ('gone', 'husband', 'loved')
# prevB:  ('gone', 'husband', 'loved')
# nextA:  ('curse', 'life', 'pp')
# nextB:  ('curse', 'life', 'voice')
# prevA is same as prev B
# prevA:  ('else', 'gone', 'husband')
# prevB:  ('else', 'gone', 'husband')
# nextA:  ('curse', 'life', 'pp')
# nextB:  ('curse', 'life', 'voice')
# prevA is same as prev B
# prevA:  ('thing', 'else', 'gone')
# prevB:  ('everything', 'else', 'gone')
# nextA:  ('curse', 'life', 'pp')
# nextB:  ('curse', 'life', 'voice')
# ('modify', 'opinion', 'excellent')
# aLocation:  2998
# bLocation:  16525
# prevA:  ('would', 'modify', 'opinion')
# prevB:  ('would', 'modify', 'opinion')
# nextA:  ('opinion', 'excellent', 'things')
# nextB:  ('opinion', 'excellent', 'things')
# prevA is same as prev B
# prevA:  ('experience', 'would', 'modify')
# prevB:  ('experience', 'would', 'modify')
# nextA:  ('opinion', 'excellent', 'things')
# nextB:  ('opinion', 'excellent', 'things')
# prevA is same as prev B
# prevA:  ('possibly', 'experience', 'would')
# prevB:  ('possibly', 'experience', 'would')
# nextA:  ('opinion', 'excellent', 'things')
# nextB:  ('opinion', 'excellent', 'things')
# prevA is same as prev B
# prevA:  ('might', 'possibly', 'experience')
# prevB:  ('might', 'possibly', 'experience')
# nextA:  ('opinion', 'excellent', 'things')
# nextB:  ('opinion', 'excellent', 'things')
# prevA is same as prev B
# prevA:  ('ripe', 'might', 'possibly')
# prevB:  ('ripe', 'might', 'possibly')
# nextA:  ('opinion', 'excellent', 'things')
# nextB:  ('opinion', 'excellent', 'things')
# prevA is same as prev B
# prevA:  ('less', 'ripe', 'might')
# prevB:  ('less', 'ripe', 'might')
# nextA:  ('opinion', 'excellent', 'things')
# nextB:  ('opinion', 'excellent', 'things')
# prevA is same as prev B
# prevA:  ('lydgate', 'less', 'ripe')
# prevB:  ('lydgate', 'less', 'ripe')
# nextA:  ('opinion', 'excellent', 'things')
# nextB:  ('opinion', 'excellent', 'things')
# prevA is same as prev B
# prevA:  ('women', 'lydgate', 'less')
# prevB:  ('bachelors', 'lydgate', 'less')
# nextA:  ('opinion', 'excellent', 'things')
# nextB:  ('opinion', 'excellent', 'things')
# next A is same as next B
# prevA:  ('women', 'lydgate', 'less')
# prevB:  ('bachelors', 'lydgate', 'less')
# nextA:  ('excellent', 'things', 'woman')
# nextB:  ('excellent', 'things', 'woman')
# next A is same as next B
# prevA:  ('women', 'lydgate', 'less')
# prevB:  ('bachelors', 'lydgate', 'less')
# nextA:  ('things', 'woman', 'motto')
# nextB:  ('things', 'woman', 'miss')
# ('seemed', 'aspects', 'likely')
# aLocation:  945
# bLocation:  535
# prevA:  ('whatever', 'seemed', 'aspects')
# prevB:  ('whatever', 'seemed', 'aspects')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('embracing', 'whatever', 'seemed')
# prevB:  ('embracing', 'whatever', 'seemed')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('rash', 'embracing', 'whatever')
# prevB:  ('rash', 'embracing', 'whatever')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('greatness', 'rash', 'embracing')
# prevB:  ('greatness', 'rash', 'embracing')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('intensity', 'greatness', 'rash')
# prevB:  ('intensity', 'greatness', 'rash')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('enamoured', 'intensity', 'greatness')
# prevB:  ('enamoured', 'intensity', 'greatness')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('conduct', 'enamoured', 'intensity')
# prevB:  ('conduct', 'enamoured', 'intensity')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('rule', 'conduct', 'enamoured')
# prevB:  ('rule', 'conduct', 'enamoured')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('tipton', 'rule', 'conduct')
# prevB:  ('tipton', 'rule', 'conduct')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('parish', 'tipton', 'rule')
# prevB:  ('parish', 'tipton', 'rule')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('include', 'parish', 'tipton')
# prevB:  ('include', 'parish', 'tipton')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('frankly', 'include', 'parish')
# prevB:  ('frankly', 'include', 'parish')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('might', 'frankly', 'include')
# prevB:  ('might', 'frankly', 'include')
# nextA:  ('aspects', 'likely', 'seek')
# nextB:  ('aspects', 'likely', 'seek')
# prevA is same as prev B
# prevA:  ('world', 'might', 'frankly')
# prevB:  ('world', 'might', 'frankly')
# nextA:  ('aspects', 'likely', 'seek')
# ...
# prevA:  ('bent', 'every', 'sweet')
# prevB:  ('bent', 'every', 'sweet')
# nextA:  ('within', 'woodenness', 'miss')
# nextB:  ('within', 'woodenness', 'wealth')
# prevA is same as prev B
# prevA:  ('caresses', 'bent', 'every')
# prevB:  ('caresses', 'bent', 'every')
# nextA:  ('within', 'woodenness', 'miss')
# nextB:  ('within', 'woodenness', 'wealth')
# prevA is same as prev B
# prevA:  ('childlike', 'caresses', 'bent')
# prevB:  ('childlike', 'caresses', 'bent')
# nextA:  ('within', 'woodenness', 'miss')
# nextB:  ('within', 'woodenness', 'wealth')
# prevA is same as prev B
# prevA:  ('shown', 'childlike', 'caresses')
# prevB:  ('affection', 'childlike', 'caresses')
# nextA:  ('within', 'woodenness', 'miss')
# nextB:  ('within', 'woodenness', 'wealth')
# ('pathology', 'fine', 'america')
# aLocation:  2075
# bLocation:  26426
# prevA:  ('territories', 'pathology', 'fine')
# prevB:  ('territories', 'pathology', 'fine')
# nextA:  ('fine', 'america', 'spirited')
# nextB:  ('fine', 'america', 'spirited')
# prevA is same as prev B
# prevA:  ('dark', 'territories', 'pathology')
# prevB:  ('dark', 'territories', 'pathology')
# nextA:  ('fine', 'america', 'spirited')
# nextB:  ('fine', 'america', 'spirited')
# prevA is same as prev B
# prevA:  ('lydgate', 'dark', 'territories')
# prevB:  ('kingdom', 'dark', 'territories')
# nextA:  ('fine', 'america', 'spirited')
# nextB:  ('fine', 'america', 'spirited')
# next A is same as next B
# prevA:  ('lydgate', 'dark', 'territories')
# prevB:  ('kingdom', 'dark', 'territories')
# nextA:  ('america', 'spirited', 'young')
# nextB:  ('america', 'spirited', 'young')
# next A is same as next B
# prevA:  ('lydgate', 'dark', 'territories')
# prevB:  ('kingdom', 'dark', 'territories')
# nextA:  ('spirited', 'young', 'adventurer')
# nextB:  ('spirited', 'young', 'adventurer')
# next A is same as next B
# prevA:  ('lydgate', 'dark', 'territories')
# prevB:  ('kingdom', 'dark', 'territories')
# nextA:  ('young', 'adventurer', 'episode')
# nextB:  ('young', 'adventurer', 'lydgate')
# ('mankind', 'perhaps', 'frames')
# aLocation:  3622
# bLocation:  35389
# prevA:  ('emotion', 'mankind', 'perhaps')
# prevB:  ('emotion', 'mankind', 'perhaps')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('coarse', 'emotion', 'mankind')
# prevB:  ('coarse', 'emotion', 'mankind')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('wrought', 'coarse', 'emotion')
# prevB:  ('wrought', 'coarse', 'emotion')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('yet', 'wrought', 'coarse')
# prevB:  ('yet', 'wrought', 'coarse')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('frequency', 'yet', 'wrought')
# prevB:  ('frequency', 'yet', 'wrought')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('fact', 'frequency', 'yet')
# prevB:  ('fact', 'frequency', 'yet')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('lies', 'fact', 'frequency')
# prevB:  ('lies', 'fact', 'frequency')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('tragedy', 'lies', 'fact')
# prevB:  ('tragedy', 'lies', 'fact')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('element', 'tragedy', 'lies')
# prevB:  ('element', 'tragedy', 'lies')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# prevA is same as prev B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('perhaps', 'frames', 'could')
# nextB:  ('perhaps', 'frames', 'could')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('frames', 'could', 'hardly')
# nextB:  ('frames', 'could', 'hardly')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('could', 'hardly', 'bear')
# nextB:  ('could', 'hardly', 'bear')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('hardly', 'bear', 'much')
# nextB:  ('hardly', 'bear', 'much')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('bear', 'much', 'keen')
# nextB:  ('bear', 'much', 'keen')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('much', 'keen', 'vision')
# nextB:  ('much', 'keen', 'vision')
# next A is same as next B
# prevA:  ('tragic', 'element', 'tragedy')
# prevB:  ('unusual', 'element', 'tragedy')
# nextA:  ('keen', 'vision', 'feeling')
# nextB:  ('keen', 'vision', 'feeling')
# next A is same as next B
# ('sister', 'given', 'self')
# aLocation:  1062
# bLocation:  2516
# prevA:  ('renounces', 'sister', 'given')
# prevB:  ('interest', 'sister', 'given')
# nextA:  ('given', 'self', 'mortification')
# nextB:  ('given', 'self', 'mortification')
# next A is same as next B
# prevA:  ('renounces', 'sister', 'given')
# prevB:  ('interest', 'sister', 'given')
# nextA:  ('self', 'mortification', 'sir')
# nextB:  ('self', 'mortification', 'continued')
# ('soon', 'took', 'form')
# aLocation:  2056
# bLocation:  25895
# prevA:  ('interest', 'soon', 'took')
# prevB:  ('interest', 'soon', 'took')
# nextA:  ('took', 'form', 'professional')
# nextB:  ('took', 'form', 'professional')
# prevA is same as prev B
# prevA:  ('scientific', 'interest', 'soon')
# prevB:  ('scientific', 'interest', 'soon')
# nextA:  ('took', 'form', 'professional')
# nextB:  ('took', 'form', 'professional')
# prevA is same as prev B
# prevA:  ('man', 'scientific', 'interest')
# prevB:  ('hope', 'scientific', 'interest')
# nextA:  ('took', 'form', 'professional')
# nextB:  ('took', 'form', 'professional')
# next A is same as next B
# prevA:  ('man', 'scientific', 'interest')
# prevB:  ('hope', 'scientific', 'interest')
# nextA:  ('form', 'professional', 'enthusi')
# nextB:  ('form', 'professional', 'enthusiasm')
# ('play', 'minute', 'causes')
# aLocation:  2584
# bLocation:  10136
# prevA:  ('show', 'play', 'minute')
# prevB:  ('show', 'play', 'minute')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('making', 'show', 'play')
# prevB:  ('making', 'show', 'play')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('match', 'making', 'show')
# prevB:  ('match', 'making', 'show')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ("cadwallader's", 'match', 'making')
# prevB:  ("cadwallader's", 'match', 'making')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('mrs', "cadwallader's", 'match')
# prevB:  ('mrs', "cadwallader's", 'match')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('applied', 'mrs', "cadwallader's")
# prevB:  ('applied', 'mrs', "cadwallader's")
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('lens', 'applied', 'mrs')
# prevB:  ('lens', 'applied', 'mrs')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('strong', 'lens', 'applied')
# prevB:  ('strong', 'lens', 'applied')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('speaking', 'strong', 'lens')
# prevB:  ('speaking', 'strong', 'lens')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('metaphorically', 'speaking', 'strong')
# prevB:  ('metaphorically', 'speaking', 'strong')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('way', 'metaphorically', 'speaking')
# prevB:  ('way', 'metaphorically', 'speaking')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('custom', 'way', 'metaphorically')
# prevB:  ('custom', 'way', 'metaphorically')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('receipt', 'custom', 'way')
# prevB:  ('receipt', 'custom', 'way')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('passively', 'receipt', 'custom')
# prevB:  ('passively', 'receipt', 'custom')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('waits', 'passively', 'receipt')
# prevB:  ('waits', 'passively', 'receipt')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# prevA:  ('swallower', 'waits', 'passively')
# prevB:  ('swallower', 'waits', 'passively')
# nextA:  ('minute', 'causes', 'producing')
# nextB:  ('minute', 'causes', 'producing')
# prevA is same as prev B
# ('known', 'difficulty', 'marriage')
# aLocation:  3762
# bLocation:  50064
# prevA:  ('woman', 'known', 'difficulty')
# prevB:  ('woman', 'known', 'difficulty')
# nextA:  ('difficulty', 'marriage', 'nevertheless')
# nextB:  ('difficulty', 'marriage', 'nay')
# prevA is same as prev B
# prevA:  ('julia', 'woman', 'known')
# prevB:  ('looking', 'woman', 'known')
# nextA:  ('difficulty', 'marriage', 'nevertheless')
# nextB:  ('difficulty', 'marriage', 'nay')
# ('active', 'voracity', 'smaller')
# aLocation:  2548
# bLocation:  10101
# prevA:  ('hibiting', 'active', 'voracity')
# prevB:  ('exhibiting', 'active', 'voracity')
# nextA:  ('voracity', 'smaller', 'creatures')
# nextB:  ('voracity', 'smaller', 'creatures')
# next A is same as next B
# prevA:  ('hibiting', 'active', 'voracity')
# prevB:  ('exhibiting', 'active', 'voracity')
# nextA:  ('smaller', 'creatures', 'ac')
# nextB:  ('smaller', 'creatures', 'actively')
# ('story', 'passion', 'development')
# aLocation:  2133
# bLocation:  25787
# prevA:  ('desires', 'story', 'passion')
# prevB:  ('desires', 'story', 'passion')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('small', 'desires', 'story')
# prevB:  ('small', 'desires', 'story')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('renunciation', 'small', 'desires')
# prevB:  ('renunciation', 'small', 'desires')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('patient', 'renunciation', 'small')
# prevB:  ('patient', 'renunciation', 'small')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('thought', 'patient', 'renunciation')
# prevB:  ('thought', 'patient', 'renunciation')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('industrious', 'thought', 'patient')
# prevB:  ('industrious', 'thought', 'patient')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('wooed', 'industrious', 'thought')
# prevB:  ('wooed', 'industrious', 'thought')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('must', 'wooed', 'industrious')
# prevB:  ('must', 'wooed', 'industrious')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('fairnesse', 'must', 'wooed')
# prevB:  ('fairnesse', 'must', 'wooed')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('makdom', 'fairnesse', 'must')
# prevB:  ('makdom', 'fairnesse', 'must')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('kind', 'makdom', 'fairnesse')
# prevB:  ('kind', 'makdom', 'fairnesse')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# prevA is same as prev B
# prevA:  ('vocation', 'kind', 'makdom')
# prevB:  ('uninterested', 'kind', 'makdom')
# nextA:  ('passion', 'development', 'varies')
# nextB:  ('passion', 'development', 'varies')
# next A is same as next B
# prevA:  ('vocation', 'kind', 'makdom')
# prevB:  ('uninterested', 'kind', 'makdom')
# nextA:  ('development', 'varies', 'sometimes')
# nextB:  ('development', 'varies', 'sometimes')
# next A is same as next B
# prevA:  ('vocation', 'kind', 'makdom')
# prevB:  ('uninterested', 'kind', 'makdom')
# nextA:  ('varies', 'sometimes', 'glorious')
# nextB:  ('varies', 'sometimes', 'glorious')
# next A is same as next B
# prevA:  ('vocation', 'kind', 'makdom')
# prevB:  ('uninterested', 'kind', 'makdom')
# nextA:  ('sometimes', 'glorious', 'marriage')
# nextB:  ('sometimes', 'glorious', 'marriage')
# next A is same as next B
# prevA:  ('vocation', 'kind', 'makdom')
# prevB:  ('uninterested', 'kind', 'makdom')
# nextA:  ('glorious', 'marriage', 'sometimes')
# nextB:  ('glorious', 'marriage', 'sometimes')
# next A is same as next B
# ('suddenly', 'brick', 'floor')
# aLocation:  970
# bLocation:  769
# prevA:  ('knelt', 'suddenly', 'brick')
# prevB:  ('knelt', 'suddenly', 'brick')
# nextA:  ('brick', 'floor', 'side')
# nextB:  ('brick', 'floor', 'side')
# prevA is same as prev B
# prevA:  ('fortune', 'knelt', 'suddenly')
# prevB:  ('fortune', 'knelt', 'suddenly')
# nextA:  ('brick', 'floor', 'side')
# nextB:  ('brick', 'floor', 'side')
# prevA is same as prev B
# prevA:  ('birth', 'fortune', 'knelt')
# prevB:  ('birth', 'fortune', 'knelt')
# nextA:  ('brick', 'floor', 'side')
# nextB:  ('brick', 'floor', 'side')
# prevA is same as prev B
# prevA:  ('lady', 'birth', 'fortune')
# prevB:  ('lady', 'birth', 'fortune')
# nextA:  ('brick', 'floor', 'side')
# nextB:  ('brick', 'floor', 'side')
# prevA is same as prev B
# prevA:  ('young', 'lady', 'birth')
# prevB:  ('young', 'lady', 'birth')
# nextA:  ('brick', 'floor', 'side')
# nextB:  ('brick', 'floor', 'side')
# prevA is same as prev B
# prevA:  ('answer', 'young', 'lady')
# prevB:  ('offers', 'young', 'lady')
# nextA:  ('brick', 'floor', 'side')
# nextB:  ('brick', 'floor', 'side')
# next A is same as next B
# prevA:  ('answer', 'young', 'lady')
# prevB:  ('offers', 'young', 'lady')
# nextA:  ('floor', 'side', 'sick')
# nextB:  ('floor', 'side', 'sick')
# next A is same as next B
# prevA:  ('answer', 'young', 'lady')
# prevB:  ('offers', 'young', 'lady')
# nextA:  ('side', 'sick', 'labourer')
# nextB:  ('side', 'sick', 'laborer')
# ('taking', 'threads', 'investigation')
# aLocation:  2603
# bLocation:  26687
# prevA:  ('lydgate', 'taking', 'threads')
# prevB:  ('seized', 'taking', 'threads')
# nextA:  ('threads', 'investigation', 'use')
# nextB:  ('threads', 'investigation', 'many')
# ('rest', 'unvisited', 'tombs')
# aLocation:  4301
# bLocation:  152485
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-bf6fde500fc0> in <module>()
# ----> 1 Match(test1Text.trigrams, mm.trigrams).extendedMatches
#
# <ipython-input-18-cd94930dee4f> in extendedMatches(self)
#      15         for match in self.initialMatches:
#      16             # Extend the match as far as possible exactly, first.
# ---> 17             match = self.extendedExactMatch(match)
#      18
#      19             # Now extend the match as far as possible fuzzily.
#
# <ipython-input-18-cd94930dee4f> in extendedExactMatch(self, match)
#      37             prevB = self.textBgrams[bLocation-pi]
#      38             nextA = self.textAgrams[aLocation+ni]
# ---> 39             nextB = self.textBgrams[bLocation+ni]
#      40             print('prevA: ', prevA)
#      41             print('prevB: ', prevB)
#
# IndexError: list index out of range

# %%
Matcher(test1Text, mm, ngramSize=2).match()
# Out:
# 25 total matches found.
# match:  Match(a=925, b=515, size=30)
#
#
# match 1:
# test1: (10484, 10893) closely, as the first description of Dorothea shows mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton and her own rule of conduct there; she was enamoured of intensity and greatness, and rash in embracing whatever seemed to her to have those aspects; likely to seek martyrdom, to make retractations, and then to incur martyrdom after all in a quarter where she had not sought central issue of marriage is raised immediately
# Middlemarch: (5809, 6218) interest in gimp and artificial protrusions of drapery mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton and her own rule of conduct there; she was enamoured of intensity and greatness, and rash in embracing whatever seemed to her to have those aspects; likely to seek martyrdom, to make retractations, and then to incur martyrdom after all in a quarter where she had not sought Certainly such elements in the character of a marriageable girl
# match:  Match(a=965, b=764, size=9)
#
#
# match 2:
# test1: (11022, 11122) immediately-"And how should Dorothea not marry?" (p. 6)-with its obvious answer young lady of some birth and fortune, who knelt suddenly down on a brick floor by the side of a sick labourer and prayed fervidly 3George Eliot's
# Middlemarch: (8751, 8851) might lead her at last to refuse all offers young lady of some birth and fortune, who knelt suddenly down on a brick floor by the side of a sick laborer and prayed fervidly as if she thought herself living
# match:  Match(a=1019, b=777, size=14)
#
#
# match 3:
# test1: (11610, 11765) parenthetically in my text. 74 NINETEENTH-CENTURY FICTION thought herself living in the time of the Apostles-who had strange whims of fasting like a Papist, and of sitting up at night to read old theological books Although the parallel relaxes, it remains the organizing
# Middlemarch: (8890, 9046) side of a sick laborer and prayed fervidly thought herself living in the time of the Apostles--who had strange whims of fasting like a Papist, and of sitting up at night to read old theological books wife might awaken you some fine morning
# match:  Match(a=1092, b=4953, size=7)
#
#
# match 4:
# test1: (12440, 12527) Dorothea's cottages on his own estate, her enthusiastic reply think we deserve to be beaten out of our beautiful houses with a scourge of small cords earlier, with Casaubon overhear- ing, she had cried
# Middlemarch: (57013, 57100) energetically, forgetting her previous small vexations think we deserve to be beaten out of our beautiful houses with a scourge of small cords us who let tenants live in such sties
# match:  Match(a=1205, b=7218, size=10)
#
#
# match 5:
# test1: (13752, 13883) letter of proposal as what we might term a "call whole soul was possessed by the fact that a fuller life was opening before her: she was a neophyte about to enter on a higher grade ini- tiation" (p. 32). This is the Dorothea of "Miss Brooke
# Middlemarch: (83868, 83999) letter, to look at it critically as a profession of love whole soul was possessed by the fact that a fuller life was opening before her: she was a neophyte about to enter on a higher grade initiation. She was going to have room for the energies which stirred
# match:  Match(a=2528, b=10082, size=17)
#
#
# match 6:
# test1: (29395, 29580) affords a glimpse of the convergent paths of the stories Even with a microscope directed on a water-drop we find ourselves making interpretations which turn out to be rather coarse; for whereas under a weak lens you may seem to see a creature ex- hibiting an active voracity into which other smaller
# Middlemarch: (116900, 117085) little of women by following them about in their pony-phaetons Even with a microscope directed on a water-drop we find ourselves making interpretations which turn out to be rather coarse; for whereas under a weak lens you may seem to see a creature exhibiting an active voracity into which other smaller creatures
# match:  Match(a=2554, b=10106, size=42)
#
#
# match 7:
# test1: (29659, 30092) voracity into which other smaller creatures ac- tively play as if they were so many animated tax-pennies, a stronger lens reveals to you certain tiniest hairlets which make vortices for these victims while the swallower waits passively at his receipt of custom. In this way, metaphorically speaking, a strong lens applied to Mrs. Cadwallader's match-making will show a play of minute causes producing what may be called thought and speech vortices to bring her the sort of food she needed images of the microscope and of microorganisms have their origin in the work
# Middlemarch: (117160, 117594) active voracity into which other smaller creatures actively play as if they were so many animated tax-pennies, a stronger lens reveals to you certain tiniest hairlets which make vortices for these victims while the swallower waits passively at his receipt of custom. In this way, metaphorically speaking, a strong lens applied to Mrs. Cadwallader's match-making will show a play of minute causes producing what may be called thought and speech vortices to bring her the sort of food she needed life was rurally simple, quite free
# match:  Match(a=2991, b=16518, size=11)
#
#
# match 8:
# test1: (34726, 34866) Lydgate's and Chichely's comparison of the two women Lydgate was less ripe, and might possibly have experience before him which would modify his opinion as to the most excellent things in woman motto comparing the two figures of ivory
# Middlemarch: (192301, 192441) fine young women to purplefaced bachelors Lydgate was less ripe, and might possibly have experience before him which would modify his opinion as to the most excellent things in woman Miss Brooke, however, was not again seen by either
# match:  Match(a=3056, b=16761, size=42)
#
#
# match 9:
# test1: (35477, 35916) Dorothea are to have in each other's lives but on the part they have already Certainly nothing at present could seem much less important to Lydgate than the turn of Miss Brooke's mind, or to Miss Brooke than the qualities of the woman who had attracted this young surgeon. But any one watching keenly the stealthy convergence of human lots, sees a slow preparation of effects from one life on another, which tells like a calculated irony on the indifference or the frozen stare with which we look at our unintroduced neigh- bour. Destiny stands by sarcastic
# Middlemarch: (195148, 195588) bird-notes, and blue eyes for a heaven Certainly nothing at present could seem much less important to Lydgate than the turn of Miss Brooke's mind, or to Miss Brooke than the qualities of the woman who had attracted this young surgeon. But any one watching keenly the stealthy convergence of human lots, sees a slow preparation of effects from one life on another, which tells like a calculated irony on the indifference or the frozen stare with which we look at our unintroduced neighbor. Destiny stands by sarcastic with our dramatis
# match:  Match(a=3101, b=16805, size=6)
#
#
# match 10:
# test1: (35930, 36003) stare with which we look at our unintroduced neigh- bour Destiny stands by sarcastic with our dramatis personae folded in her hand next see Dorothea she is on her wedding trip
# Middlemarch: (195600, 195673) frozen stare with which we look at our unintroduced neighbor Destiny stands by sarcastic with our dramatis personae folded in her hand Old provincial society had its share of this subtle
# match:  Match(a=3258, b=34612, size=12)
#
#
# match 11:
# test1: (37725, 37845) Ariadne, a religious depth for which her Puritanism does not account Antique form animated by Christian sentiment-a sort of Christian Antigone-sensuous force controlled by spiritual passion None of this serves to advance Middlemarch. Under the new
# Middlemarch: (402604, 402726) would think of Mistress Second-Cousin antique form animated by Christian sentiment--a sort of Christian Antigone--sensuous force controlled by spiritual passion Yes, and that your painting her was the chief outcome of her existence
# match:  Match(a=3613, b=35380, size=40)
#
#
# match 12:
# test1: (42065, 42515) Eliot cannot suppose we will regard as tragic element of tragedy which lies in the very fact of frequency, has not yet wrought itself into the coarse emotion of mankind; and perhaps our frames could hardly bear much of it. If we had a keen vision and feeling of all ordinary human life, it would be like hearing the grass grow and the squirrel's heart beat, and we should die of that roar which lies on the other side of silence. As it is, the quickest of us walk about well wadded with stupidity end of the next chapter, after her quarrel with Casaubon
# Middlemarch: (411725, 412177) expect people to be deeply moved by what is not unusual element of tragedy which lies in the very fact of frequency, has not yet wrought itself into the coarse emotion of mankind; and perhaps our frames could hardly bear much of it. If we had a keen vision and feeling of all ordinary human life, it would be like hearing the grass grow and the squirrel's heart beat, and we should die of that roar which lies on the other side of silence. As it is, the quickest of us walk about well wadded with stupidity However, Dorothea was crying, and if she had been required to state
# match:  Match(a=3668, b=38424, size=41)
#
#
# match 13:
# test1: (42700, 43207) good of the world" is thoroughly laid: To-day begun to see that she had been under a wild illusion in expecting a response to her feeling from Mr. Casaubon, and she had felt the waking of a presentiment that there might be a sad consciousness in his life which made as great a need on his side as on her own. We are all of us born in moral stupidity, taking the world as an udder to feed our supreme selves: Dorothea had early begun to emerge from that stupidity, but yet it had been easier to her to imagine how she would devote herself to Mr. Casaubon come wise and strong in his strength and wisdom
# Middlemarch: (449403, 449911) dies, or some new motive is born. Today begun to see that she had been under a wild illusion in expecting a response to her feeling from Mr. Casaubon, and she had felt the waking of a presentiment that there might be a sad consciousness in his life which made as great a need on his side as on her own. We are all of us born in moral stupidity, taking the world as an udder to feed our supreme selves: Dorothea had early begun to emerge from that stupidity, but yet it had been easier to her to imagine how she would devote herself to Mr. Casaubon become wise and strong in his strength and wisdom
# match:  Match(a=3711, b=38467, size=8)
#
#
# match 14:
# test1: (43222, 43347) would devote herself to Mr. Casaubon, and be- come wise and strong in his strength and wisdom, than to conceive with that distinctness which is no longer reflection but feeling equivalent centre of self, whence the lights
# Middlemarch: (449924, 450049) would devote herself to Mr. Casaubon, and become wise and strong in his strength and wisdom, than to conceive with that distinctness which is no longer reflection but feeling idea wrought back to the directness of sense
# match:  Match(a=3720, b=38484, size=10)
#
#
# match 15:
# test1: (43367, 43466) conceive with that distinctness which is no longer reflection but feeling equivalent centre of self, whence the lights and shadows must always fall with a certain difference pp. 156- 57) Given this major development in the scheme
# Middlemarch: (450145, 450244) directness of sense, like the solidity of objects equivalent centre of self, whence the lights and shadows must always fall with a certain difference CHAPTER XXII. "Nous câusames longtemps
# match:  Match(a=3836, b=134340, size=9)
#
#
# match 16:
# test1: (44773, 44882) practical action on behalf of a friend and neighbor Would you not like to be the one person who believed in that man's innocence, if the rest of the world belied People glorify all sorts of bravery except
# Middlemarch: (1575265, 1575374) cruel!" said Dorothea, clasping her hands would you not like to be the one person who believed in that man's innocence, if the rest of the world belied Besides, there is a man's character beforehand to speak
# match:  Match(a=3846, b=134428, size=9)
#
#
# match 17:
# test1: (44892, 44989) man's innocence, if the rest of the world belied People glorify all sorts of bravery except the bravery they might show on behalf of their nearest neighbours" (p. 538). Her instinctive understanding of what is tragic in Lydgate's
# Middlemarch: (1576340, 1576437) clear. Then we would all stand by him and bring him out of his trouble People glorify all sorts of bravery except the bravery they might show on behalf of their nearest neighbors." Dorothea's eyes had a moist brightness
# match:  Match(a=3922, b=140368, size=36)
#
#
# match 18:
# test1: (45831, 46249) Miss Brooke. As he rides away he thinks young creature has a heart large enough for the Virgin Mary. She evidently thinks nothing of her own future, and would pledge away half her income at once, as if she wanted nothing for herself but a chair to sit in from which she can look down with those clear eyes at the poor mortals who pray to her. She seems to have what I never saw in any woman before-a fountain of friendship towards men-a man can make a friend Ca- saubon must have raised some heroic
# Middlemarch: (1648987, 1649408) like me." As Lydgate rode away, he thought young creature has a heart large enough for the Virgin Mary. She evidently thinks nothing of her own future, and would pledge away half her income at once, as if she wanted nothing for herself but a chair to sit in from which she can look down with those clear eyes at the poor mortals who pray to her. She seems to have what I never saw in any woman before--a fountain of friendship towards men--a man can make a friend Casaubon must have raised some heroic hallucination
# match:  Match(a=3967, b=140411, size=16)
#
#
# match 19:
# test1: (46338, 46542) raised some heroic hallucination in her. I won- der could have any other sort of passion for a man? Ladislaw?-there was certainly an unusual feeling between them. And Casaubon must have had a notion of it. Well-her love might help a man more than her money NINETEENTH-CENTURY FICTION What Dorothea has thought
# Middlemarch: (1649495, 1649704) must have raised some heroic hallucination in her. I wonder could have any other sort of passion for a man? Ladislaw?--there was certainly an unusual feeling between them. And Casaubon must have had a notion of it. Well--her love might help a man more than her money Dorothea on her side had immediately formed a plan
# match:  Match(a=4040, b=143674, size=10)
#
#
# match 20:
# test1: (47322, 47456) intellect. During her night watch in the cold room began now to live through that yesterday morning deliberately again, forcing herself to dwell on every detail and its possible meaning active thought with which she had before been representing to herself the trials of Lydgate's
# Middlemarch: (1688955, 1689089) consciousness that only sees another's lot as an accident began now to live through that yesterday morning deliberately again, forcing herself to dwell on every detail and its possible meaning alone in that scene? Was it her event only? She forced herself to think
# match:  Match(a=4051, b=143747, size=16)
#
#
# match 21:
# test1: (47469, 47699) dwell on every detail and its possible meaning active thought with which she had before been representing to herself the trials of Lydgate's lot, and this young marriage union which, like her own, seemed to have its hidden as well as evident troubles-all this vivid sympathetic ex- perience returned to her now as a power: it asserted
# Middlemarch: (1689915, 1690146) tumult and had once shown her the truer measure of things active thought with which she had before been representing to herself the trials of Lydgate's lot, and this young marriage union which, like her own, seemed to have its hidden as well as evident troubles--all this vivid sympathetic experience returned to her now as a power: it asserted itself as acquired
# match:  Match(a=4070, b=143765, size=11)
#
#
# match 22:
# test1: (47713, 47862) troubles-all this vivid sympathetic ex- perience returned to her now as a power: it asserted itself as acquired knowledge asserts itself and will not let us see as we saw in the day of our ignorance victory of knowledge over self, Dorothea proves
# Middlemarch: (1690158, 1690307) evident troubles--all this vivid sympathetic experience returned to her now as a power: it asserted itself as acquired knowledge asserts itself and will not let us see as we saw in the day of our ignorance said to her own irremediable grief, that it should make her more helpful
# match:  Match(a=4183, b=145308, size=18)
#
#
# match 23:
# test1: (49114, 49317) else better than-than those we were married to, it would be no use mean, marriage drinks up all our power of giving or getting any blessedness in that sort of love. I know it may be very dear-but it murders our marriage- and then the marriage stays with us like a murder every- thing else is gone. And then our husband
# Middlemarch: (1708999, 1709204) anxiety, could only seize her language brokenly mean, marriage drinks up all our power of giving or getting any blessedness in that sort of love. I know it may be very dear--but it murders our marriage--and then the marriage stays with us like a murder everything else is gone. And then our husband--if he loved
# match:  Match(a=4204, b=145328, size=9)
#
#
# match 24:
# test1: (49335, 49454) us like a murder-and every- thing else is gone. And then our husband-if he loved and trusted us, and we have not helped him, but made a curse in his life pp. 583-84) Here is the true reason for her overlong mourning
# Middlemarch: (1709221, 1709342) stays with us like a murder--and everything else is gone. And then our husband--if he loved and trusted us, and we have not helped him, but made a curse in his life voice had sunk very low: there was a dread upon
# match:  Match(a=4280, b=152464, size=23)
#
#
# match 25:
# test1: (50226, 50531) real value of lives like Dorothea's effect of her being on those around her was incalculably diffusive: for the growing good of the world is partly dependent on unhistoric acts; and that things are not so ill with you and me as they might have been, is half owing to the number who lived faithfully a hidden life, and rest in unvisited tombs joining of "Miss Brooke" and "Middlemarch" suggested
# Middlemarch: (1793142, 1793447) spent itself in channels which had no great name on the earth effect of her being on those around her was incalculably diffusive: for the growing good of the world is partly dependent on unhistoric acts; and that things are not so ill with you and me as they might have been, is half owing to the number who lived faithfully a hidden life, and rest in unvisited tombs
# (25,
#  [(10484, 10893),
#   (11022, 11122),
#   (11610, 11765),
#   (12440, 12527),
#   (13752, 13883),
#   (29395, 29580),
#   (29659, 30092),
#   (34726, 34866),
#   (35477, 35916),
#   (35930, 36003),
#   (37725, 37845),
#   (42065, 42515),
#   (42700, 43207),
#   (43222, 43347),
#   (43367, 43466),
#   (44773, 44882),
#   (44892, 44989),
#   (45831, 46249),
#   (46338, 46542),
#   (47322, 47456),
#   (47469, 47699),
#   (47713, 47862),
#   (49114, 49317),
#   (49335, 49454),
#   (50226, 50531)],
#  [(5809, 6218),
#   (8751, 8851),
#   (8890, 9046),
#   (57013, 57100),
#   (83868, 83999),
#   (116900, 117085),
#   (117160, 117594),
#   (192301, 192441),
#   (195148, 195588),
#   (195600, 195673),
#   (402604, 402726),
#   (411725, 412177),
#   (449403, 449911),
#   (449924, 450049),
#   (450145, 450244),
#   (1575265, 1575374),
#   (1576340, 1576437),
#   (1648987, 1649408),
#   (1649495, 1649704),
#   (1688955, 1689089),
#   (1689915, 1690146),
#   (1690158, 1690307),
#   (1708999, 1709204),
#   (1709221, 1709342),
#   (1793142, 1793447)])

# %%
Matcher(test1Text, mm, threshold=2, ngramSize=1).match()
# Out:
# 33 total matches found.
# match:  Match(a=157, b=0, size=3)
#
#
# match 1:
# test1: (1742, 1772) inspiration whose final result is the novel Middlemarch. When George Eliot embarked on "Miss Brooke" in November 1870, she was undertaking
# Middlemarch: (3, 33)  Middlemarch By George Eliot PRELUDE Who that cares much to know the history
# match:  Match(a=925, b=515, size=31)
#
#
# match 2:
# test1: (10484, 10893) closely, as the first description of Dorothea shows mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton and her own rule of conduct there; she was enamoured of intensity and greatness, and rash in embracing whatever seemed to her to have those aspects; likely to seek martyrdom, to make retractations, and then to incur martyrdom after all in a quarter where she had not sought central issue of marriage is raised immediately
# Middlemarch: (5809, 6218) interest in gimp and artificial protrusions of drapery mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton and her own rule of conduct there; she was enamoured of intensity and greatness, and rash in embracing whatever seemed to her to have those aspects; likely to seek martyrdom, to make retractations, and then to incur martyrdom after all in a quarter where she had not sought Certainly such elements in the character of a marriageable girl
# match:  Match(a=965, b=764, size=10)
#
#
# match 3:
# test1: (11022, 11122) immediately-"And how should Dorothea not marry?" (p. 6)-with its obvious answer young lady of some birth and fortune, who knelt suddenly down on a brick floor by the side of a sick labourer and prayed fervidly 3George Eliot's
# Middlemarch: (8751, 8851) might lead her at last to refuse all offers young lady of some birth and fortune, who knelt suddenly down on a brick floor by the side of a sick laborer and prayed fervidly as if she thought herself living
# match:  Match(a=1019, b=777, size=15)
#
#
# match 4:
# test1: (11610, 11765) parenthetically in my text. 74 NINETEENTH-CENTURY FICTION thought herself living in the time of the Apostles-who had strange whims of fasting like a Papist, and of sitting up at night to read old theological books Although the parallel relaxes, it remains the organizing
# Middlemarch: (8890, 9046) side of a sick laborer and prayed fervidly thought herself living in the time of the Apostles--who had strange whims of fasting like a Papist, and of sitting up at night to read old theological books wife might awaken you some fine morning
# match:  Match(a=1062, b=2516, size=4)
#
#
# match 5:
# test1: (12082, 12119) Casaubon, for instance, Dorothea immediately renounces sister is given to self-mortification Sir James says to Celia, who an- swers
# Middlemarch: (28768, 28805) tone of reproach that showed strong interest sister is given to self-mortification continued, turning to Celia, who sat at his right
# match:  Match(a=1092, b=4953, size=8)
#
#
# match 6:
# test1: (12440, 12527) Dorothea's cottages on his own estate, her enthusiastic reply think we deserve to be beaten out of our beautiful houses with a scourge of small cords earlier, with Casaubon overhear- ing, she had cried
# Middlemarch: (57013, 57100) energetically, forgetting her previous small vexations think we deserve to be beaten out of our beautiful houses with a scourge of small cords us who let tenants live in such sties
# match:  Match(a=1205, b=7218, size=11)
#
#
# match 7:
# test1: (13752, 13883) letter of proposal as what we might term a "call whole soul was possessed by the fact that a fuller life was opening before her: she was a neophyte about to enter on a higher grade ini- tiation" (p. 32). This is the Dorothea of "Miss Brooke
# Middlemarch: (83868, 83999) letter, to look at it critically as a profession of love whole soul was possessed by the fact that a fuller life was opening before her: she was a neophyte about to enter on a higher grade initiation. She was going to have room for the energies which stirred
# match:  Match(a=2528, b=10082, size=18)
#
#
# match 8:
# test1: (29395, 29580) affords a glimpse of the convergent paths of the stories Even with a microscope directed on a water-drop we find ourselves making interpretations which turn out to be rather coarse; for whereas under a weak lens you may seem to see a creature ex- hibiting an active voracity into which other smaller
# Middlemarch: (116900, 117085) little of women by following them about in their pony-phaetons Even with a microscope directed on a water-drop we find ourselves making interpretations which turn out to be rather coarse; for whereas under a weak lens you may seem to see a creature exhibiting an active voracity into which other smaller creatures
# match:  Match(a=2548, b=10101, size=4)
#
#
# match 9:
# test1: (29597, 29647) seem to see a creature ex- hibiting active voracity into which other smaller creatures ac- tively play as if they were so many animated
# Middlemarch: (117100, 117150) may seem to see a creature exhibiting active voracity into which other smaller creatures actively play as if they were so many animated tax
# match:  Match(a=2554, b=10106, size=43)
#
#
# match 10:
# test1: (29659, 30092) voracity into which other smaller creatures ac- tively play as if they were so many animated tax-pennies, a stronger lens reveals to you certain tiniest hairlets which make vortices for these victims while the swallower waits passively at his receipt of custom. In this way, metaphorically speaking, a strong lens applied to Mrs. Cadwallader's match-making will show a play of minute causes producing what may be called thought and speech vortices to bring her the sort of food she needed images of the microscope and of microorganisms have their origin in the work
# Middlemarch: (117160, 117594) active voracity into which other smaller creatures actively play as if they were so many animated tax-pennies, a stronger lens reveals to you certain tiniest hairlets which make vortices for these victims while the swallower waits passively at his receipt of custom. In this way, metaphorically speaking, a strong lens applied to Mrs. Cadwallader's match-making will show a play of minute causes producing what may be called thought and speech vortices to bring her the sort of food she needed life was rurally simple, quite free
# match:  Match(a=2991, b=16518, size=12)
#
#
# match 11:
# test1: (34726, 34866) Lydgate's and Chichely's comparison of the two women Lydgate was less ripe, and might possibly have experience before him which would modify his opinion as to the most excellent things in woman motto comparing the two figures of ivory
# Middlemarch: (192301, 192441) fine young women to purplefaced bachelors Lydgate was less ripe, and might possibly have experience before him which would modify his opinion as to the most excellent things in woman Miss Brooke, however, was not again seen by either
# match:  Match(a=3056, b=16761, size=43)
#
#
# match 12:
# test1: (35477, 35916) Dorothea are to have in each other's lives but on the part they have already Certainly nothing at present could seem much less important to Lydgate than the turn of Miss Brooke's mind, or to Miss Brooke than the qualities of the woman who had attracted this young surgeon. But any one watching keenly the stealthy convergence of human lots, sees a slow preparation of effects from one life on another, which tells like a calculated irony on the indifference or the frozen stare with which we look at our unintroduced neigh- bour. Destiny stands by sarcastic
# Middlemarch: (195148, 195588) bird-notes, and blue eyes for a heaven Certainly nothing at present could seem much less important to Lydgate than the turn of Miss Brooke's mind, or to Miss Brooke than the qualities of the woman who had attracted this young surgeon. But any one watching keenly the stealthy convergence of human lots, sees a slow preparation of effects from one life on another, which tells like a calculated irony on the indifference or the frozen stare with which we look at our unintroduced neighbor. Destiny stands by sarcastic with our dramatis
# match:  Match(a=3101, b=16805, size=7)
#
#
# match 13:
# test1: (35930, 36003) stare with which we look at our unintroduced neigh- bour Destiny stands by sarcastic with our dramatis personae folded in her hand next see Dorothea she is on her wedding trip
# Middlemarch: (195600, 195673) frozen stare with which we look at our unintroduced neighbor Destiny stands by sarcastic with our dramatis personae folded in her hand Old provincial society had its share of this subtle
# match:  Match(a=3258, b=34612, size=13)
#
#
# match 14:
# test1: (37725, 37845) Ariadne, a religious depth for which her Puritanism does not account Antique form animated by Christian sentiment-a sort of Christian Antigone-sensuous force controlled by spiritual passion None of this serves to advance Middlemarch. Under the new
# Middlemarch: (402604, 402726) would think of Mistress Second-Cousin antique form animated by Christian sentiment--a sort of Christian Antigone--sensuous force controlled by spiritual passion Yes, and that your painting her was the chief outcome of her existence
# match:  Match(a=3613, b=35380, size=41)
#
#
# match 15:
# test1: (42065, 42515) Eliot cannot suppose we will regard as tragic element of tragedy which lies in the very fact of frequency, has not yet wrought itself into the coarse emotion of mankind; and perhaps our frames could hardly bear much of it. If we had a keen vision and feeling of all ordinary human life, it would be like hearing the grass grow and the squirrel's heart beat, and we should die of that roar which lies on the other side of silence. As it is, the quickest of us walk about well wadded with stupidity end of the next chapter, after her quarrel with Casaubon
# Middlemarch: (411725, 412177) expect people to be deeply moved by what is not unusual element of tragedy which lies in the very fact of frequency, has not yet wrought itself into the coarse emotion of mankind; and perhaps our frames could hardly bear much of it. If we had a keen vision and feeling of all ordinary human life, it would be like hearing the grass grow and the squirrel's heart beat, and we should die of that roar which lies on the other side of silence. As it is, the quickest of us walk about well wadded with stupidity However, Dorothea was crying, and if she had been required to state
# match:  Match(a=3668, b=38424, size=42)
#
#
# match 16:
# test1: (42700, 43207) good of the world" is thoroughly laid: To-day begun to see that she had been under a wild illusion in expecting a response to her feeling from Mr. Casaubon, and she had felt the waking of a presentiment that there might be a sad consciousness in his life which made as great a need on his side as on her own. We are all of us born in moral stupidity, taking the world as an udder to feed our supreme selves: Dorothea had early begun to emerge from that stupidity, but yet it had been easier to her to imagine how she would devote herself to Mr. Casaubon come wise and strong in his strength and wisdom
# Middlemarch: (449403, 449911) dies, or some new motive is born. Today begun to see that she had been under a wild illusion in expecting a response to her feeling from Mr. Casaubon, and she had felt the waking of a presentiment that there might be a sad consciousness in his life which made as great a need on his side as on her own. We are all of us born in moral stupidity, taking the world as an udder to feed our supreme selves: Dorothea had early begun to emerge from that stupidity, but yet it had been easier to her to imagine how she would devote herself to Mr. Casaubon become wise and strong in his strength and wisdom
# match:  Match(a=3711, b=38467, size=9)
#
#
# match 17:
# test1: (43222, 43347) would devote herself to Mr. Casaubon, and be- come wise and strong in his strength and wisdom, than to conceive with that distinctness which is no longer reflection but feeling equivalent centre of self, whence the lights
# Middlemarch: (449924, 450049) would devote herself to Mr. Casaubon, and become wise and strong in his strength and wisdom, than to conceive with that distinctness which is no longer reflection but feeling idea wrought back to the directness of sense
# match:  Match(a=3720, b=38484, size=11)
#
#
# match 18:
# test1: (43367, 43466) conceive with that distinctness which is no longer reflection but feeling equivalent centre of self, whence the lights and shadows must always fall with a certain difference pp. 156- 57) Given this major development in the scheme
# Middlemarch: (450145, 450244) directness of sense, like the solidity of objects equivalent centre of self, whence the lights and shadows must always fall with a certain difference CHAPTER XXII. "Nous câusames longtemps
# match:  Match(a=3761, b=50063, size=4)
#
#
# match 19:
# test1: (43860, 43910) feels a "new companionship" with Aunt Julia woman who had known some difficulty about marriage Nevertheless, Casaubon's sexual jealousy remains
# Middlemarch: (585739, 585789) companionship with it, as if it had an ear for her and could see how she was looking woman who had known some difficulty about marriage Nay, the colors deepened, the lips and chin
# match:  Match(a=3804, b=113751, size=3)
#
#
# match 20:
# test1: (44423, 44444) hour, when her and Lydgate's stories converge again, is the result direct fellow feeling releases two other people from the isolation of their suffering
# Middlemarch: (1327698, 1327719) morality if unchecked by the deep-seated habit direct fellow-feeling individual fellow-men. But a man who believes
# match:  Match(a=3836, b=134340, size=10)
#
#
# match 21:
# test1: (44773, 44882) practical action on behalf of a friend and neighbor Would you not like to be the one person who believed in that man's innocence, if the rest of the world belied People glorify all sorts of bravery except
# Middlemarch: (1575265, 1575374) cruel!" said Dorothea, clasping her hands would you not like to be the one person who believed in that man's innocence, if the rest of the world belied Besides, there is a man's character beforehand to speak
# match:  Match(a=3846, b=134428, size=10)
#
#
# match 22:
# test1: (44892, 44989) man's innocence, if the rest of the world belied People glorify all sorts of bravery except the bravery they might show on behalf of their nearest neighbours" (p. 538). Her instinctive understanding of what is tragic in Lydgate's
# Middlemarch: (1576340, 1576437) clear. Then we would all stand by him and bring him out of his trouble People glorify all sorts of bravery except the bravery they might show on behalf of their nearest neighbors." Dorothea's eyes had a moist brightness
# match:  Match(a=3869, b=139547, size=6)
#
#
# match 23:
# test1: (45203, 45259) expe- rience: "There is no sorrow I have thought more about than that," she says love what is great, and try to reach it, and yet to fail sorrow has been made immediate to her by Casaubon's life
# Middlemarch: (1638981, 1639037) first spoke to me about the hospital. There is no sorrow I have thought love what is great, and try to reach it, and yet to fail Yes," said Lydgate, feeling that here he had found
# match:  Match(a=3922, b=140368, size=37)
#
#
# match 24:
# test1: (45831, 46249) Miss Brooke. As he rides away he thinks young creature has a heart large enough for the Virgin Mary. She evidently thinks nothing of her own future, and would pledge away half her income at once, as if she wanted nothing for herself but a chair to sit in from which she can look down with those clear eyes at the poor mortals who pray to her. She seems to have what I never saw in any woman before-a fountain of friendship towards men-a man can make a friend Ca- saubon must have raised some heroic
# Middlemarch: (1648987, 1649408) like me." As Lydgate rode away, he thought young creature has a heart large enough for the Virgin Mary. She evidently thinks nothing of her own future, and would pledge away half her income at once, as if she wanted nothing for herself but a chair to sit in from which she can look down with those clear eyes at the poor mortals who pray to her. She seems to have what I never saw in any woman before--a fountain of friendship towards men--a man can make a friend Casaubon must have raised some heroic hallucination
# match:  Match(a=3961, b=140406, size=4)
#
#
# match 25:
# test1: (46269, 46311) man can make a friend of her. Ca- saubon must have raised some heroic hallucination won- der if she could have any other sort of passion
# Middlemarch: (1649427, 1649469) men--a man can make a friend of her. Casaubon must have raised some heroic hallucination wonder if she could have any other sort of passion for a man
# match:  Match(a=3967, b=140411, size=17)
#
#
# match 26:
# test1: (46338, 46542) raised some heroic hallucination in her. I won- der could have any other sort of passion for a man? Ladislaw?-there was certainly an unusual feeling between them. And Casaubon must have had a notion of it. Well-her love might help a man more than her money NINETEENTH-CENTURY FICTION What Dorothea has thought
# Middlemarch: (1649495, 1649704) must have raised some heroic hallucination in her. I wonder could have any other sort of passion for a man? Ladislaw?--there was certainly an unusual feeling between them. And Casaubon must have had a notion of it. Well--her love might help a man more than her money Dorothea on her side had immediately formed a plan
# match:  Match(a=4040, b=143674, size=11)
#
#
# match 27:
# test1: (47322, 47456) intellect. During her night watch in the cold room began now to live through that yesterday morning deliberately again, forcing herself to dwell on every detail and its possible meaning active thought with which she had before been representing to herself the trials of Lydgate's
# Middlemarch: (1688955, 1689089) consciousness that only sees another's lot as an accident began now to live through that yesterday morning deliberately again, forcing herself to dwell on every detail and its possible meaning alone in that scene? Was it her event only? She forced herself to think
# match:  Match(a=4051, b=143747, size=17)
#
#
# match 28:
# test1: (47469, 47699) dwell on every detail and its possible meaning active thought with which she had before been representing to herself the trials of Lydgate's lot, and this young marriage union which, like her own, seemed to have its hidden as well as evident troubles-all this vivid sympathetic ex- perience returned to her now as a power: it asserted
# Middlemarch: (1689915, 1690146) tumult and had once shown her the truer measure of things active thought with which she had before been representing to herself the trials of Lydgate's lot, and this young marriage union which, like her own, seemed to have its hidden as well as evident troubles--all this vivid sympathetic experience returned to her now as a power: it asserted itself as acquired
# match:  Match(a=4070, b=143765, size=12)
#
#
# match 29:
# test1: (47713, 47862) troubles-all this vivid sympathetic ex- perience returned to her now as a power: it asserted itself as acquired knowledge asserts itself and will not let us see as we saw in the day of our ignorance victory of knowledge over self, Dorothea proves
# Middlemarch: (1690158, 1690307) evident troubles--all this vivid sympathetic experience returned to her now as a power: it asserted itself as acquired knowledge asserts itself and will not let us see as we saw in the day of our ignorance said to her own irremediable grief, that it should make her more helpful
# match:  Match(a=4178, b=145295, size=5)
#
#
# match 30:
# test1: (49041, 49107) BROOKE" TO MIDDLEMARCH 89 "Even if we loved someone else better than-than those we were married to, it would be no use mean, marriage drinks up all our power of giving
# Middlemarch: (1708843, 1708910) nearness it brings. Even if we loved some one else better than--than those we were married to, it would be no use poor Dorothea, in her palpitating anxiety, could
# match:  Match(a=4183, b=145308, size=19)
#
#
# match 31:
# test1: (49114, 49317) else better than-than those we were married to, it would be no use mean, marriage drinks up all our power of giving or getting any blessedness in that sort of love. I know it may be very dear-but it murders our marriage- and then the marriage stays with us like a murder every- thing else is gone. And then our husband
# Middlemarch: (1708999, 1709204) anxiety, could only seize her language brokenly mean, marriage drinks up all our power of giving or getting any blessedness in that sort of love. I know it may be very dear--but it murders our marriage--and then the marriage stays with us like a murder everything else is gone. And then our husband--if he loved
# match:  Match(a=4204, b=145328, size=10)
#
#
# match 32:
# test1: (49335, 49454) us like a murder-and every- thing else is gone. And then our husband-if he loved and trusted us, and we have not helped him, but made a curse in his life pp. 583-84) Here is the true reason for her overlong mourning
# Middlemarch: (1709221, 1709342) stays with us like a murder--and everything else is gone. And then our husband--if he loved and trusted us, and we have not helped him, but made a curse in his life voice had sunk very low: there was a dread upon
# match:  Match(a=4280, b=152464, size=24)
#
#
# match 33:
# test1: (50226, 50531) real value of lives like Dorothea's effect of her being on those around her was incalculably diffusive: for the growing good of the world is partly dependent on unhistoric acts; and that things are not so ill with you and me as they might have been, is half owing to the number who lived faithfully a hidden life, and rest in unvisited tombs joining of "Miss Brooke" and "Middlemarch" suggested
# Middlemarch: (1793142, 1793447) spent itself in channels which had no great name on the earth effect of her being on those around her was incalculably diffusive: for the growing good of the world is partly dependent on unhistoric acts; and that things are not so ill with you and me as they might have been, is half owing to the number who lived faithfully a hidden life, and rest in unvisited tombs
# (33,
#  [(1742, 1772),
#   (10484, 10893),
#   (11022, 11122),
#   (11610, 11765),
#   (12082, 12119),
#   (12440, 12527),
#   (13752, 13883),
#   (29395, 29580),
#   (29597, 29647),
#   (29659, 30092),
#   (34726, 34866),
#   (35477, 35916),
#   (35930, 36003),
#   (37725, 37845),
#   (42065, 42515),
#   (42700, 43207),
#   (43222, 43347),
#   (43367, 43466),
#   (43860, 43910),
#   (44423, 44444),
#   (44773, 44882),
#   (44892, 44989),
#   (45203, 45259),
#   (45831, 46249),
#   (46269, 46311),
#   (46338, 46542),
#   (47322, 47456),
#   (47469, 47699),
#   (47713, 47862),
#   (49041, 49107),
#   (49114, 49317),
#   (49335, 49454),
#   (50226, 50531)],
#  [(3, 33),
#   (5809, 6218),
#   (8751, 8851),
#   (8890, 9046),
#   (28768, 28805),
#   (57013, 57100),
#   (83868, 83999),
#   (116900, 117085),
#   (117100, 117150),
#   (117160, 117594),
#   (192301, 192441),
#   (195148, 195588),
#   (195600, 195673),
#   (402604, 402726),
#   (411725, 412177),
#   (449403, 449911),
#   (449924, 450049),
#   (450145, 450244),
#   (585739, 585789),
#   (1327698, 1327719),
#   (1575265, 1575374),
#   (1576340, 1576437),
#   (1638981, 1639037),
#   (1648987, 1649408),
#   (1649427, 1649469),
#   (1649495, 1649704),
#   (1688955, 1689089),
#   (1689915, 1690146),
#   (1690158, 1690307),
#   (1708843, 1708910),
#   (1708999, 1709204),
#   (1709221, 1709342),
#   (1793142, 1793447)])

# %%
test9text = Text(tests[9], 'test9')

# %%
Matcher(test9text, mm).match()
# Out:
# 16 total matches found.
# match:  Match(a=1145, b=341, size=16)
#
#
# match 1:
# test9: (13769, 13998) opening passage of Middlemarch: [Dorothea Brooke usually spoken of (1) as being remarkably clever, but with the addition that her sister Celia had more common sense. Nevertheless, Celia wore scarcely more trimmings; and it was only to close observers (2) that her dress differed sister’s, and had a shade of coquetry in its arrangements; for Miss
# Middlemarch: (3790, 4011) elder poets,--in a paragraph of to-day's newspaper usually spoken of as being remarkably clever, but with the addition that her sister Celia had more common-sense. Nevertheless, Celia wore scarcely more trimmings; and it was only to close observers that her dress differed sister's, and had a shade of coquetry in its arrangements; for Miss
# match:  Match(a=1172, b=367, size=28)
#
#
# match 2:
# test9: (14106, 14474) Miss Brooke’s plain dress- ing due to mixed conditions, in most of which her sister shared. The pride of being ladies had something to do with it: the Brooke connections, though not exactly aristocratic, were unquestionably (3) ‘good’: if you (4) inquired backward for a generation or two, you would not find any yard-measuring or parcel-tying forefathers—anything lower than an admiral or clergyman Young women of such birth, living in a quiet
# Middlemarch: (4117, 4481) arrangements; for Miss Brooke's plain dressing due to mixed conditions, in most of which her sister shared. The pride of being ladies had something to do with it: the Brooke connections, though not exactly aristocratic, were unquestionably "good:" if you inquired backward for a generation or two, you would not find any yard-measuring or parcel-tying forefathers--anything lower than an admiral or a clergyman even an ancestor discernible as a Puritan gentleman
# match:  Match(a=1202, b=414, size=10)
#
#
# match 3:
# test9: (14482, 14586) forefathers—anything lower than an admiral or clergyman Young women of such birth, living in a quiet country-house, and attending a village church hardly larger parlour, naturally (5) regarded frippery as the ambition
# Middlemarch: (4703, 4807) troubles as the proprietor of a respectable family estate Young women of such birth, living in a quiet country-house, and attending a village church hardly larger parlor, naturally regarded frippery as the ambition
# match:  Match(a=1220, b=432, size=14)
#
#
# match 4:
# test9: (14667, 14856) naturally (5) regarded frippery as the ambition of a huckster daughter. Then there was well-bred economy, which in those days (6) made show in dress the first item to be deducted from, when any margin was required for expenses more distinctive of rank Dorothea’s] mind was theoretic, and yearned by its nature
# Middlemarch: (4883, 5069) naturally regarded frippery as the ambition of a huckster's daughter. Then there was well-bred economy, which in those days made show in dress the first item to be deducted from, when any margin was required for expenses more distinctive of rank reasons would have been enough to account for plain
# match:  Match(a=1237, b=515, size=12)
#
#
# match 5:
# test9: (14877, 15044) required for expenses more distinctive of rank. . . . [Dorothea mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton (7) and her own rule of conduct Certainly such elements in the character of a marriageable girl
# Middlemarch: (5809, 5972) interest in gimp and artificial protrusions of drapery mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton and her own rule of conduct enamoured of intensity and greatness, and rash in embracing
# match:  Match(a=1251, b=546, size=16)
#
#
# match 6:
# test9: (15058, 15264) include the parish of Tipton (7) and her own rule of conduct Certainly such elements in the character of a marriageable girl tended to interfere with her lot, and hinder it from being decided according to custom (8), by good looks, vanity, and merely canine affection hardly a year since [Dorothea and Celia
# Middlemarch: (6224, 6426) retractations, and then to incur martyrdom after all in a quarter where she had not sought Certainly such elements in the character of a marriageable girl tended to interfere with her lot, and hinder it from being decided according to custom, by good looks, vanity, and merely canine affection elder of the sisters, was not yet twenty, and they had both been educated
# match:  Match(a=1274, b=597, size=23)
#
#
# match 7:
# test9: (15324, 15593) hardly a year since [Dorothea and Celia come to live at Tipton Grange with their uncle, a man nearly sixty, of acquiescent temper, miscellaneous opinions, and uncertain vote. He had travelled in his younger years, and was held in this part of the county (9) to have contracted a too rambling habit of mind. Mr Brooke’s conclusions were as difficult to predict (10) as the weather
# Middlemarch: (6856, 7123) orphaned condition. It was hardly a year since come to live at Tipton Grange with their uncle, a man nearly sixty, of acquiescent temper, miscellaneous opinions, and uncertain vote. He had travelled in his younger years, and was held in this part of the county to have contracted a too rambling habit of mind. Mr Brooke's conclusions were as difficult to predict as the weather
# match:  Match(a=1300, b=623, size=14)
#
#
# match 8:
# test9: (15603, 15803) rambling habit of mind. Mr Brooke conclusions were as difficult to predict (10) as the weather: it was only safe to say (11) that he would act with benevolent intentions, and that he would spend as little money as possible in carrying Dorothea] was regarded as (12) an heiress, for not only had the sisters seven
# Middlemarch: (7134, 7324) rambling habit of mind. Mr. Brooke's conclusions were as difficult to predict as the weather: it was only safe to say that he would act with benevolent intentions, and that he would spend as little money as possible in carrying glutinously indefinite minds enclose some hard
# match:  Match(a=1317, b=691, size=12)
#
#
# match 9:
# test9: (15835, 16003) little money as possible in carrying them out. . . . [Dorothea regarded as (12) an heiress, for not only had the sisters seven hundred a year each from their parents, but if Dorothea married and had a son, that son would inherit Mr Brooke’s estate, presumably worth about three
# Middlemarch: (7962, 8125) age and have some command of money for generous schemes regarded as an heiress; for not only had the sisters seven hundred a-year each from their parents, but if Dorothea married and had a son, that son would inherit Mr Brooke's estate, presumably worth about three
# match:  Match(a=1332, b=706, size=9)
#
#
# match 10:
# test9: (16013, 16117) son would inherit Mr Brooke estate, presumably worth about three thousand a year—a rental which seemed wealth to provincial families Dorothea not marry?—a girl so handsome and with such prospects
# Middlemarch: (8136, 8241) son would inherit Mr. Brooke's estate, presumably worth about three thousand a-year--a rental which seemed wealth to provincial families still discussing Mr. Peel's late
# match:  Match(a=1343, b=736, size=26)
#
#
# match 11:
# test9: (16146, 16450) rental which seemed wealth to provincial families Dorothea not marry?—a girl so handsome and with such prospects? (14) Nothing could hinder it but her love of extremes, and her insistence on regulating life according to notions which might cause a wary man (15) to hesitate before he made her an offer, or even might lead her at last to refuse all offers man would naturally (16) think twice
# Middlemarch: (8450, 8746) nobly exalted the necessities of genteel life Dorothea not marry?--a girl so handsome and with such prospects? Nothing could hinder it but her love of extremes, and her insistence on regulating life according to notions which might cause a wary man to hesitate before he made her an offer, or even might lead her at last to refuse all offers young lady of some birth and fortune, who knelt
# match:  Match(a=1371, b=808, size=18)
#
#
# match 12:
# test9: (16460, 16695) might lead her at last to refuse all offers man would naturally (16) think twice before he risked himself in such fellowship. Women were expected (17) to have weak opinions; but the great safeguard of society and of domestic life was, that opinions were not acted on. Sane people neighbours did (19), so that if any lunatics (20) were at large, one (21) might
# Middlemarch: (9229, 9456) political economy and the keeping of saddle-horses man would naturally think twice before he risked himself in such fellowship. Women were expected to have weak opinions; but the great safeguard of society and of domestic life was, that opinions were not acted on. Sane people neighbors did, so that if any lunatics were at large, one might
# match:  Match(a=1392, b=829, size=12)
#
#
# match 13:
# test9: (16752, 16887) opinions were not acted on. Sane people did (18) what their neighbours lunatics (20) were at large, one (21) might know and avoid them. The rural opinion about the new young ladies, even among the cottagers gener- ally in favour of Celia, as being so amiable
# Middlemarch: (9502, 9628) opinions were not acted on. Sane people did what their neighbors lunatics were at large, one might know and avoid them. The rural opinion about the new young ladies, even among the cottagers generally in favor of Celia, as being so amiable and innocent
# match:  Match(a=1426, b=880, size=11)
#
#
# match 14:
# test9: (17110, 17307) striking. . . . Yet those who (23) approached 432 Alan Palmer Dorothea, though prejudiced against her by this alarming hearsay (24) , found that she had a charm unaccountably reconcilable with it. Most men (25) thought her bewitching when she was on horseback peculiarities of Dorothea’s character caused Mr
# Middlemarch: (10016, 10203) blazonry or clock-face for it. Yet those who approached Dorothea, though prejudiced against her by this alarming hearsay, found that she had a charm unaccountably reconcilable with it. Most men thought her bewitching when she was on horseback loved the fresh air and the various aspects
# match:  Match(a=1455, b=1046, size=9)
#
#
# match 15:
# test9: (17503, 17652) aged lady as guide and com- panion nieces. But he himself dreaded so much the sort of superior woman likely to be available for such a position, that he allowed himself to be dissuaded Dorothea’s objections, and was in this case brave enough
# Middlemarch: (12014, 12164) middle-aged lady as guide and companion nieces. But he himself dreaded so much the sort of superior woman likely to be available for such a position, that he allowed himself to be dissuaded Dorothea's objections, and was in this case brave enough
# match:  Match(a=1467, b=1058, size=7)
#
#
# match 16:
# test9: (17667, 17762) available for such a position, that he allowed himself to be dissuaded by Dorothea objections, and was in this case brave enough to defy the world—that is to say, Mrs Cadwallader Rector’s wife, and the small group of gentry
# Middlemarch: (12179, 12276) available for such a position, that he allowed himself to be dissuaded by Dorothea's objections, and was in this case brave enough to defy the world--that is to say, Mrs. Cadwallader Rector's wife, and the small group of gentry
# (16,
#  [(13769, 13998),
#   (14106, 14474),
#   (14482, 14586),
#   (14667, 14856),
#   (14877, 15044),
#   (15058, 15264),
#   (15324, 15593),
#   (15603, 15803),
#   (15835, 16003),
#   (16013, 16117),
#   (16146, 16450),
#   (16460, 16695),
#   (16752, 16887),
#   (17110, 17307),
#   (17503, 17652),
#   (17667, 17762)],
#  [(3790, 4011),
#   (4117, 4481),
#   (4703, 4807),
#   (4883, 5069),
#   (5809, 5972),
#   (6224, 6426),
#   (6856, 7123),
#   (7134, 7324),
#   (7962, 8125),
#   (8136, 8241),
#   (8450, 8746),
#   (9229, 9456),
#   (9502, 9628),
#   (10016, 10203),
#   (12014, 12164),
#   (12179, 12276)])

# %%
Matcher(test9text, mm, threshold=2).match()
# Out:
# 24 total matches found.
# match:  Match(a=1145, b=341, size=16)
#
#
# match 1:
# test9: (13769, 13998) opening passage of Middlemarch: [Dorothea Brooke usually spoken of (1) as being remarkably clever, but with the addition that her sister Celia had more common sense. Nevertheless, Celia wore scarcely more trimmings; and it was only to close observers (2) that her dress differed sister’s, and had a shade of coquetry in its arrangements; for Miss
# Middlemarch: (3790, 4011) elder poets,--in a paragraph of to-day's newspaper usually spoken of as being remarkably clever, but with the addition that her sister Celia had more common-sense. Nevertheless, Celia wore scarcely more trimmings; and it was only to close observers that her dress differed sister's, and had a shade of coquetry in its arrangements; for Miss
# match:  Match(a=1172, b=367, size=28)
#
#
# match 2:
# test9: (14106, 14474) Miss Brooke’s plain dress- ing due to mixed conditions, in most of which her sister shared. The pride of being ladies had something to do with it: the Brooke connections, though not exactly aristocratic, were unquestionably (3) ‘good’: if you (4) inquired backward for a generation or two, you would not find any yard-measuring or parcel-tying forefathers—anything lower than an admiral or clergyman Young women of such birth, living in a quiet
# Middlemarch: (4117, 4481) arrangements; for Miss Brooke's plain dressing due to mixed conditions, in most of which her sister shared. The pride of being ladies had something to do with it: the Brooke connections, though not exactly aristocratic, were unquestionably "good:" if you inquired backward for a generation or two, you would not find any yard-measuring or parcel-tying forefathers--anything lower than an admiral or a clergyman even an ancestor discernible as a Puritan gentleman
# match:  Match(a=1202, b=414, size=10)
#
#
# match 3:
# test9: (14482, 14586) forefathers—anything lower than an admiral or clergyman Young women of such birth, living in a quiet country-house, and attending a village church hardly larger parlour, naturally (5) regarded frippery as the ambition
# Middlemarch: (4703, 4807) troubles as the proprietor of a respectable family estate Young women of such birth, living in a quiet country-house, and attending a village church hardly larger parlor, naturally regarded frippery as the ambition
# match:  Match(a=1220, b=432, size=14)
#
#
# match 4:
# test9: (14667, 14856) naturally (5) regarded frippery as the ambition of a huckster daughter. Then there was well-bred economy, which in those days (6) made show in dress the first item to be deducted from, when any margin was required for expenses more distinctive of rank Dorothea’s] mind was theoretic, and yearned by its nature
# Middlemarch: (4883, 5069) naturally regarded frippery as the ambition of a huckster's daughter. Then there was well-bred economy, which in those days made show in dress the first item to be deducted from, when any margin was required for expenses more distinctive of rank reasons would have been enough to account for plain
# match:  Match(a=1237, b=515, size=12)
#
#
# match 5:
# test9: (14877, 15044) required for expenses more distinctive of rank. . . . [Dorothea mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton (7) and her own rule of conduct Certainly such elements in the character of a marriageable girl
# Middlemarch: (5809, 5972) interest in gimp and artificial protrusions of drapery mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton and her own rule of conduct enamoured of intensity and greatness, and rash in embracing
# match:  Match(a=1251, b=546, size=16)
#
#
# match 6:
# test9: (15058, 15264) include the parish of Tipton (7) and her own rule of conduct Certainly such elements in the character of a marriageable girl tended to interfere with her lot, and hinder it from being decided according to custom (8), by good looks, vanity, and merely canine affection hardly a year since [Dorothea and Celia
# Middlemarch: (6224, 6426) retractations, and then to incur martyrdom after all in a quarter where she had not sought Certainly such elements in the character of a marriageable girl tended to interfere with her lot, and hinder it from being decided according to custom, by good looks, vanity, and merely canine affection elder of the sisters, was not yet twenty, and they had both been educated
# match:  Match(a=1274, b=597, size=23)
#
#
# match 7:
# test9: (15324, 15593) hardly a year since [Dorothea and Celia come to live at Tipton Grange with their uncle, a man nearly sixty, of acquiescent temper, miscellaneous opinions, and uncertain vote. He had travelled in his younger years, and was held in this part of the county (9) to have contracted a too rambling habit of mind. Mr Brooke’s conclusions were as difficult to predict (10) as the weather
# Middlemarch: (6856, 7123) orphaned condition. It was hardly a year since come to live at Tipton Grange with their uncle, a man nearly sixty, of acquiescent temper, miscellaneous opinions, and uncertain vote. He had travelled in his younger years, and was held in this part of the county to have contracted a too rambling habit of mind. Mr Brooke's conclusions were as difficult to predict as the weather
# match:  Match(a=1300, b=623, size=14)
#
#
# match 8:
# test9: (15603, 15803) rambling habit of mind. Mr Brooke conclusions were as difficult to predict (10) as the weather: it was only safe to say (11) that he would act with benevolent intentions, and that he would spend as little money as possible in carrying Dorothea] was regarded as (12) an heiress, for not only had the sisters seven
# Middlemarch: (7134, 7324) rambling habit of mind. Mr. Brooke's conclusions were as difficult to predict as the weather: it was only safe to say that he would act with benevolent intentions, and that he would spend as little money as possible in carrying glutinously indefinite minds enclose some hard
# match:  Match(a=1317, b=691, size=12)
#
#
# match 9:
# test9: (15835, 16003) little money as possible in carrying them out. . . . [Dorothea regarded as (12) an heiress, for not only had the sisters seven hundred a year each from their parents, but if Dorothea married and had a son, that son would inherit Mr Brooke’s estate, presumably worth about three
# Middlemarch: (7962, 8125) age and have some command of money for generous schemes regarded as an heiress; for not only had the sisters seven hundred a-year each from their parents, but if Dorothea married and had a son, that son would inherit Mr Brooke's estate, presumably worth about three
# match:  Match(a=1332, b=706, size=9)
#
#
# match 10:
# test9: (16013, 16117) son would inherit Mr Brooke estate, presumably worth about three thousand a year—a rental which seemed wealth to provincial families Dorothea not marry?—a girl so handsome and with such prospects
# Middlemarch: (8136, 8241) son would inherit Mr. Brooke's estate, presumably worth about three thousand a-year--a rental which seemed wealth to provincial families still discussing Mr. Peel's late
# match:  Match(a=1343, b=736, size=26)
#
#
# match 11:
# test9: (16146, 16450) rental which seemed wealth to provincial families Dorothea not marry?—a girl so handsome and with such prospects? (14) Nothing could hinder it but her love of extremes, and her insistence on regulating life according to notions which might cause a wary man (15) to hesitate before he made her an offer, or even might lead her at last to refuse all offers man would naturally (16) think twice
# Middlemarch: (8450, 8746) nobly exalted the necessities of genteel life Dorothea not marry?--a girl so handsome and with such prospects? Nothing could hinder it but her love of extremes, and her insistence on regulating life according to notions which might cause a wary man to hesitate before he made her an offer, or even might lead her at last to refuse all offers young lady of some birth and fortune, who knelt
# match:  Match(a=1371, b=808, size=18)
#
#
# match 12:
# test9: (16460, 16695) might lead her at last to refuse all offers man would naturally (16) think twice before he risked himself in such fellowship. Women were expected (17) to have weak opinions; but the great safeguard of society and of domestic life was, that opinions were not acted on. Sane people neighbours did (19), so that if any lunatics (20) were at large, one (21) might
# Middlemarch: (9229, 9456) political economy and the keeping of saddle-horses man would naturally think twice before he risked himself in such fellowship. Women were expected to have weak opinions; but the great safeguard of society and of domestic life was, that opinions were not acted on. Sane people neighbors did, so that if any lunatics were at large, one might
# match:  Match(a=1392, b=829, size=12)
#
#
# match 13:
# test9: (16752, 16887) opinions were not acted on. Sane people did (18) what their neighbours lunatics (20) were at large, one (21) might know and avoid them. The rural opinion about the new young ladies, even among the cottagers gener- ally in favour of Celia, as being so amiable
# Middlemarch: (9502, 9628) opinions were not acted on. Sane people did what their neighbors lunatics were at large, one might know and avoid them. The rural opinion about the new young ladies, even among the cottagers generally in favor of Celia, as being so amiable and innocent
# match:  Match(a=1409, b=845, size=3)
#
#
# match 14:
# test9: (16923, 16982) among the cottagers (22), was gener- ally in favour Celia, as being so amiable and innocent-looking, while Miss Brooke’s large eyes seemed, like
# Middlemarch: (9656, 9715) even among the cottagers, was generally in favor Celia, as being so amiable and innocent-looking, while Miss Brooke's large eyes seemed, like
# match:  Match(a=1415, b=851, size=5)
#
#
# match 15:
# test9: (16992, 17054) amiable and innocent-looking, while Miss Brooke large eyes seemed, like her religion, too unusual and striking Yet those who (23) approached 432 Alan Palmer Dorothea
# Middlemarch: (9725, 9787) amiable and innocent-looking, while Miss Brooke's large eyes seemed, like her religion, too unusual and striking Poor Dorothea! compared with her, the innocent-looking
# match:  Match(a=1426, b=880, size=11)
#
#
# match 16:
# test9: (17110, 17307) striking. . . . Yet those who (23) approached 432 Alan Palmer Dorothea, though prejudiced against her by this alarming hearsay (24) , found that she had a charm unaccountably reconcilable with it. Most men (25) thought her bewitching when she was on horseback peculiarities of Dorothea’s character caused Mr
# Middlemarch: (10016, 10203) blazonry or clock-face for it. Yet those who approached Dorothea, though prejudiced against her by this alarming hearsay, found that she had a charm unaccountably reconcilable with it. Most men thought her bewitching when she was on horseback loved the fresh air and the various aspects
# match:  Match(a=1441, b=1033, size=3)
#
#
# match 17:
# test9: (17349, 17401) thought her bewitching when she was on horseback. . . . These peculiarities of Dorothea character caused Mr Brooke to be all the more blamed neighbouring families (26) for not securing some middle-aged
# Middlemarch: (11867, 11920) even Hebrew, if you wished it. These peculiarities of Dorothea's character caused Mr. Brooke to be all the more blamed neighboring families for not securing some middle-aged
# match:  Match(a=1447, b=1039, size=4)
#
#
# match 18:
# test9: (17418, 17479) caused Mr Brooke to be all the more blamed in neighbouring families (26) for not securing some middle-aged lady as guide com- panion to his nieces. But he himself dreaded so much
# Middlemarch: (11936, 11992) caused Mr. Brooke to be all the more blamed in neighboring families for not securing some middle-aged lady as guide companion to his nieces. But he himself dreaded so much the sort
# match:  Match(a=1455, b=1046, size=9)
#
#
# match 19:
# test9: (17503, 17652) aged lady as guide and com- panion nieces. But he himself dreaded so much the sort of superior woman likely to be available for such a position, that he allowed himself to be dissuaded Dorothea’s objections, and was in this case brave enough
# Middlemarch: (12014, 12164) middle-aged lady as guide and companion nieces. But he himself dreaded so much the sort of superior woman likely to be available for such a position, that he allowed himself to be dissuaded Dorothea's objections, and was in this case brave enough
# match:  Match(a=1467, b=1058, size=7)
#
#
# match 20:
# test9: (17667, 17762) available for such a position, that he allowed himself to be dissuaded by Dorothea objections, and was in this case brave enough to defy the world—that is to say, Mrs Cadwallader Rector’s wife, and the small group of gentry
# Middlemarch: (12179, 12276) available for such a position, that he allowed himself to be dissuaded by Dorothea's objections, and was in this case brave enough to defy the world--that is to say, Mrs. Cadwallader Rector's wife, and the small group of gentry
# match:  Match(a=1477, b=1068, size=3)
#
#
# match 21:
# test9: (17776, 17832) world—that is to say, Mrs Cadwallader the Rector wife, and the small group of gentry with whom he visited north-east corner of Loamshire. (27) So Miss
# Middlemarch: (12290, 12346) world--that is to say, Mrs. Cadwallader the Rector's wife, and the small group of gentry with whom he visited northeast corner of Loamshire. So Miss Brooke
# match:  Match(a=1484, b=1074, size=3)
#
#
# match 22:
# test9: (17851, 17900) group of gentry with whom he visited in the north-east corner of Loamshire. (27) So Miss Brooke presided uncle’s household, and did not at all dislike her new authority
# Middlemarch: (12364, 12409) small group of gentry with whom he visited in the northeast corner of Loamshire. So Miss Brooke presided uncle's household, and did not at all dislike her new authority
# match:  Match(a=1490, b=1080, size=4)
#
#
# match 23:
# test9: (17916, 18002) Loamshire. (27) So Miss Brooke presided in her uncle household, and did not at all dislike her new authority, with the homage that belonged would guess that this passage would strike
# Middlemarch: (12425, 12511) Loamshire. So Miss Brooke presided in her uncle's household, and did not at all dislike her new authority, with the homage that belonged Sir James Chettam was going to dine
# match:  Match(a=2700, b=27684, size=5)
#
#
# match 24:
# test9: (33013, 33102) cheated with that quotation. The actual words in the text Middlemarch, in fact, counted on swallowing Lydgate and assimilating him very comfortably understand very easily what that sentence means when we encounter
# Middlemarch: (321957, 322046) knowledge as to the way in which life had been shaping him for that instrumentality Middlemarch, in fact, counted on swallowing Lydgate and assimilating him very comfortably CHAPTER XVI. "All that in woman is adored In thy
# (24,
#  [(13769, 13998),
#   (14106, 14474),
#   (14482, 14586),
#   (14667, 14856),
#   (14877, 15044),
#   (15058, 15264),
#   (15324, 15593),
#   (15603, 15803),
#   (15835, 16003),
#   (16013, 16117),
#   (16146, 16450),
#   (16460, 16695),
#   (16752, 16887),
#   (16923, 16982),
#   (16992, 17054),
#   (17110, 17307),
#   (17349, 17401),
#   (17418, 17479),
#   (17503, 17652),
#   (17667, 17762),
#   (17776, 17832),
#   (17851, 17900),
#   (17916, 18002),
#   (33013, 33102)],
#  [(3790, 4011),
#   (4117, 4481),
#   (4703, 4807),
#   (4883, 5069),
#   (5809, 5972),
#   (6224, 6426),
#   (6856, 7123),
#   (7134, 7324),
#   (7962, 8125),
#   (8136, 8241),
#   (8450, 8746),
#   (9229, 9456),
#   (9502, 9628),
#   (9656, 9715),
#   (9725, 9787),
#   (10016, 10203),
#   (11867, 11920),
#   (11936, 11992),
#   (12014, 12164),
#   (12179, 12276),
#   (12290, 12346),
#   (12364, 12409),
#   (12425, 12511),
#   (321957, 322046)])

# %%
Matcher(test9text, mm, threshold=2, removeStopwords=False).match()
# Out:
# 24 total matches found.
# match:  Match(a=1145, b=341, size=16)
#
#
# match 1:
# test9: (13769, 13998) opening passage of Middlemarch: [Dorothea Brooke usually spoken of (1) as being remarkably clever, but with the addition that her sister Celia had more common sense. Nevertheless, Celia wore scarcely more trimmings; and it was only to close observers (2) that her dress differed sister’s, and had a shade of coquetry in its arrangements; for Miss
# Middlemarch: (3790, 4011) elder poets,--in a paragraph of to-day's newspaper usually spoken of as being remarkably clever, but with the addition that her sister Celia had more common-sense. Nevertheless, Celia wore scarcely more trimmings; and it was only to close observers that her dress differed sister's, and had a shade of coquetry in its arrangements; for Miss
# match:  Match(a=1172, b=367, size=28)
#
#
# match 2:
# test9: (14106, 14474) Miss Brooke’s plain dress- ing due to mixed conditions, in most of which her sister shared. The pride of being ladies had something to do with it: the Brooke connections, though not exactly aristocratic, were unquestionably (3) ‘good’: if you (4) inquired backward for a generation or two, you would not find any yard-measuring or parcel-tying forefathers—anything lower than an admiral or clergyman Young women of such birth, living in a quiet
# Middlemarch: (4117, 4481) arrangements; for Miss Brooke's plain dressing due to mixed conditions, in most of which her sister shared. The pride of being ladies had something to do with it: the Brooke connections, though not exactly aristocratic, were unquestionably "good:" if you inquired backward for a generation or two, you would not find any yard-measuring or parcel-tying forefathers--anything lower than an admiral or a clergyman even an ancestor discernible as a Puritan gentleman
# match:  Match(a=1202, b=414, size=10)
#
#
# match 3:
# test9: (14482, 14586) forefathers—anything lower than an admiral or clergyman Young women of such birth, living in a quiet country-house, and attending a village church hardly larger parlour, naturally (5) regarded frippery as the ambition
# Middlemarch: (4703, 4807) troubles as the proprietor of a respectable family estate Young women of such birth, living in a quiet country-house, and attending a village church hardly larger parlor, naturally regarded frippery as the ambition
# match:  Match(a=1220, b=432, size=14)
#
#
# match 4:
# test9: (14667, 14856) naturally (5) regarded frippery as the ambition of a huckster daughter. Then there was well-bred economy, which in those days (6) made show in dress the first item to be deducted from, when any margin was required for expenses more distinctive of rank Dorothea’s] mind was theoretic, and yearned by its nature
# Middlemarch: (4883, 5069) naturally regarded frippery as the ambition of a huckster's daughter. Then there was well-bred economy, which in those days made show in dress the first item to be deducted from, when any margin was required for expenses more distinctive of rank reasons would have been enough to account for plain
# match:  Match(a=1237, b=515, size=12)
#
#
# match 5:
# test9: (14877, 15044) required for expenses more distinctive of rank. . . . [Dorothea mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton (7) and her own rule of conduct Certainly such elements in the character of a marriageable girl
# Middlemarch: (5809, 5972) interest in gimp and artificial protrusions of drapery mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton and her own rule of conduct enamoured of intensity and greatness, and rash in embracing
# match:  Match(a=1251, b=546, size=16)
#
#
# match 6:
# test9: (15058, 15264) include the parish of Tipton (7) and her own rule of conduct Certainly such elements in the character of a marriageable girl tended to interfere with her lot, and hinder it from being decided according to custom (8), by good looks, vanity, and merely canine affection hardly a year since [Dorothea and Celia
# Middlemarch: (6224, 6426) retractations, and then to incur martyrdom after all in a quarter where she had not sought Certainly such elements in the character of a marriageable girl tended to interfere with her lot, and hinder it from being decided according to custom, by good looks, vanity, and merely canine affection elder of the sisters, was not yet twenty, and they had both been educated
# match:  Match(a=1274, b=597, size=23)
#
#
# match 7:
# test9: (15324, 15593) hardly a year since [Dorothea and Celia come to live at Tipton Grange with their uncle, a man nearly sixty, of acquiescent temper, miscellaneous opinions, and uncertain vote. He had travelled in his younger years, and was held in this part of the county (9) to have contracted a too rambling habit of mind. Mr Brooke’s conclusions were as difficult to predict (10) as the weather
# Middlemarch: (6856, 7123) orphaned condition. It was hardly a year since come to live at Tipton Grange with their uncle, a man nearly sixty, of acquiescent temper, miscellaneous opinions, and uncertain vote. He had travelled in his younger years, and was held in this part of the county to have contracted a too rambling habit of mind. Mr Brooke's conclusions were as difficult to predict as the weather
# match:  Match(a=1300, b=623, size=14)
#
#
# match 8:
# test9: (15603, 15803) rambling habit of mind. Mr Brooke conclusions were as difficult to predict (10) as the weather: it was only safe to say (11) that he would act with benevolent intentions, and that he would spend as little money as possible in carrying Dorothea] was regarded as (12) an heiress, for not only had the sisters seven
# Middlemarch: (7134, 7324) rambling habit of mind. Mr. Brooke's conclusions were as difficult to predict as the weather: it was only safe to say that he would act with benevolent intentions, and that he would spend as little money as possible in carrying glutinously indefinite minds enclose some hard
# match:  Match(a=1317, b=691, size=12)
#
#
# match 9:
# test9: (15835, 16003) little money as possible in carrying them out. . . . [Dorothea regarded as (12) an heiress, for not only had the sisters seven hundred a year each from their parents, but if Dorothea married and had a son, that son would inherit Mr Brooke’s estate, presumably worth about three
# Middlemarch: (7962, 8125) age and have some command of money for generous schemes regarded as an heiress; for not only had the sisters seven hundred a-year each from their parents, but if Dorothea married and had a son, that son would inherit Mr Brooke's estate, presumably worth about three
# match:  Match(a=1332, b=706, size=9)
#
#
# match 10:
# test9: (16013, 16117) son would inherit Mr Brooke estate, presumably worth about three thousand a year—a rental which seemed wealth to provincial families Dorothea not marry?—a girl so handsome and with such prospects
# Middlemarch: (8136, 8241) son would inherit Mr. Brooke's estate, presumably worth about three thousand a-year--a rental which seemed wealth to provincial families still discussing Mr. Peel's late
# match:  Match(a=1343, b=736, size=26)
#
#
# match 11:
# test9: (16146, 16450) rental which seemed wealth to provincial families Dorothea not marry?—a girl so handsome and with such prospects? (14) Nothing could hinder it but her love of extremes, and her insistence on regulating life according to notions which might cause a wary man (15) to hesitate before he made her an offer, or even might lead her at last to refuse all offers man would naturally (16) think twice
# Middlemarch: (8450, 8746) nobly exalted the necessities of genteel life Dorothea not marry?--a girl so handsome and with such prospects? Nothing could hinder it but her love of extremes, and her insistence on regulating life according to notions which might cause a wary man to hesitate before he made her an offer, or even might lead her at last to refuse all offers young lady of some birth and fortune, who knelt
# match:  Match(a=1371, b=808, size=18)
#
#
# match 12:
# test9: (16460, 16695) might lead her at last to refuse all offers man would naturally (16) think twice before he risked himself in such fellowship. Women were expected (17) to have weak opinions; but the great safeguard of society and of domestic life was, that opinions were not acted on. Sane people neighbours did (19), so that if any lunatics (20) were at large, one (21) might
# Middlemarch: (9229, 9456) political economy and the keeping of saddle-horses man would naturally think twice before he risked himself in such fellowship. Women were expected to have weak opinions; but the great safeguard of society and of domestic life was, that opinions were not acted on. Sane people neighbors did, so that if any lunatics were at large, one might
# match:  Match(a=1392, b=829, size=12)
#
#
# match 13:
# test9: (16752, 16887) opinions were not acted on. Sane people did (18) what their neighbours lunatics (20) were at large, one (21) might know and avoid them. The rural opinion about the new young ladies, even among the cottagers gener- ally in favour of Celia, as being so amiable
# Middlemarch: (9502, 9628) opinions were not acted on. Sane people did what their neighbors lunatics were at large, one might know and avoid them. The rural opinion about the new young ladies, even among the cottagers generally in favor of Celia, as being so amiable and innocent
# match:  Match(a=1409, b=845, size=3)
#
#
# match 14:
# test9: (16923, 16982) among the cottagers (22), was gener- ally in favour Celia, as being so amiable and innocent-looking, while Miss Brooke’s large eyes seemed, like
# Middlemarch: (9656, 9715) even among the cottagers, was generally in favor Celia, as being so amiable and innocent-looking, while Miss Brooke's large eyes seemed, like
# match:  Match(a=1415, b=851, size=5)
#
#
# match 15:
# test9: (16992, 17054) amiable and innocent-looking, while Miss Brooke large eyes seemed, like her religion, too unusual and striking Yet those who (23) approached 432 Alan Palmer Dorothea
# Middlemarch: (9725, 9787) amiable and innocent-looking, while Miss Brooke's large eyes seemed, like her religion, too unusual and striking Poor Dorothea! compared with her, the innocent-looking
# match:  Match(a=1426, b=880, size=11)
#
#
# match 16:
# test9: (17110, 17307) striking. . . . Yet those who (23) approached 432 Alan Palmer Dorothea, though prejudiced against her by this alarming hearsay (24) , found that she had a charm unaccountably reconcilable with it. Most men (25) thought her bewitching when she was on horseback peculiarities of Dorothea’s character caused Mr
# Middlemarch: (10016, 10203) blazonry or clock-face for it. Yet those who approached Dorothea, though prejudiced against her by this alarming hearsay, found that she had a charm unaccountably reconcilable with it. Most men thought her bewitching when she was on horseback loved the fresh air and the various aspects
# match:  Match(a=1441, b=1033, size=3)
#
#
# match 17:
# test9: (17349, 17401) thought her bewitching when she was on horseback. . . . These peculiarities of Dorothea character caused Mr Brooke to be all the more blamed neighbouring families (26) for not securing some middle-aged
# Middlemarch: (11867, 11920) even Hebrew, if you wished it. These peculiarities of Dorothea's character caused Mr. Brooke to be all the more blamed neighboring families for not securing some middle-aged
# match:  Match(a=1447, b=1039, size=4)
#
#
# match 18:
# test9: (17418, 17479) caused Mr Brooke to be all the more blamed in neighbouring families (26) for not securing some middle-aged lady as guide com- panion to his nieces. But he himself dreaded so much
# Middlemarch: (11936, 11992) caused Mr. Brooke to be all the more blamed in neighboring families for not securing some middle-aged lady as guide companion to his nieces. But he himself dreaded so much the sort
# match:  Match(a=1455, b=1046, size=9)
#
#
# match 19:
# test9: (17503, 17652) aged lady as guide and com- panion nieces. But he himself dreaded so much the sort of superior woman likely to be available for such a position, that he allowed himself to be dissuaded Dorothea’s objections, and was in this case brave enough
# Middlemarch: (12014, 12164) middle-aged lady as guide and companion nieces. But he himself dreaded so much the sort of superior woman likely to be available for such a position, that he allowed himself to be dissuaded Dorothea's objections, and was in this case brave enough
# match:  Match(a=1467, b=1058, size=7)
#
#
# match 20:
# test9: (17667, 17762) available for such a position, that he allowed himself to be dissuaded by Dorothea objections, and was in this case brave enough to defy the world—that is to say, Mrs Cadwallader Rector’s wife, and the small group of gentry
# Middlemarch: (12179, 12276) available for such a position, that he allowed himself to be dissuaded by Dorothea's objections, and was in this case brave enough to defy the world--that is to say, Mrs. Cadwallader Rector's wife, and the small group of gentry
# match:  Match(a=1477, b=1068, size=3)
#
#
# match 21:
# test9: (17776, 17832) world—that is to say, Mrs Cadwallader the Rector wife, and the small group of gentry with whom he visited north-east corner of Loamshire. (27) So Miss
# Middlemarch: (12290, 12346) world--that is to say, Mrs. Cadwallader the Rector's wife, and the small group of gentry with whom he visited northeast corner of Loamshire. So Miss Brooke
# match:  Match(a=1484, b=1074, size=3)
#
#
# match 22:
# test9: (17851, 17900) group of gentry with whom he visited in the north-east corner of Loamshire. (27) So Miss Brooke presided uncle’s household, and did not at all dislike her new authority
# Middlemarch: (12364, 12409) small group of gentry with whom he visited in the northeast corner of Loamshire. So Miss Brooke presided uncle's household, and did not at all dislike her new authority
# match:  Match(a=1490, b=1080, size=4)
#
#
# match 23:
# test9: (17916, 18002) Loamshire. (27) So Miss Brooke presided in her uncle household, and did not at all dislike her new authority, with the homage that belonged would guess that this passage would strike
# Middlemarch: (12425, 12511) Loamshire. So Miss Brooke presided in her uncle's household, and did not at all dislike her new authority, with the homage that belonged Sir James Chettam was going to dine
# match:  Match(a=2700, b=27684, size=5)
#
#
# match 24:
# test9: (33013, 33102) cheated with that quotation. The actual words in the text Middlemarch, in fact, counted on swallowing Lydgate and assimilating him very comfortably understand very easily what that sentence means when we encounter
# Middlemarch: (321957, 322046) knowledge as to the way in which life had been shaping him for that instrumentality Middlemarch, in fact, counted on swallowing Lydgate and assimilating him very comfortably CHAPTER XVI. "All that in woman is adored In thy
# (24,
#  [(13769, 13998),
#   (14106, 14474),
#   (14482, 14586),
#   (14667, 14856),
#   (14877, 15044),
#   (15058, 15264),
#   (15324, 15593),
#   (15603, 15803),
#   (15835, 16003),
#   (16013, 16117),
#   (16146, 16450),
#   (16460, 16695),
#   (16752, 16887),
#   (16923, 16982),
#   (16992, 17054),
#   (17110, 17307),
#   (17349, 17401),
#   (17418, 17479),
#   (17503, 17652),
#   (17667, 17762),
#   (17776, 17832),
#   (17851, 17900),
#   (17916, 18002),
#   (33013, 33102)],
#  [(3790, 4011),
#   (4117, 4481),
#   (4703, 4807),
#   (4883, 5069),
#   (5809, 5972),
#   (6224, 6426),
#   (6856, 7123),
#   (7134, 7324),
#   (7962, 8125),
#   (8136, 8241),
#   (8450, 8746),
#   (9229, 9456),
#   (9502, 9628),
#   (9656, 9715),
#   (9725, 9787),
#   (10016, 10203),
#   (11867, 11920),
#   (11936, 11992),
#   (12014, 12164),
#   (12179, 12276),
#   (12290, 12346),
#   (12364, 12409),
#   (12425, 12511),
#   (321957, 322046)])

# %%
Matcher(test9text, mm, ngramSize=1, threshold=2).match()
# Out:
# 27 total matches found.
# match:  Match(a=1145, b=341, size=18)
#
#
# match 1:
# test9: (13769, 13998) opening passage of Middlemarch: [Dorothea Brooke usually spoken of (1) as being remarkably clever, but with the addition that her sister Celia had more common sense. Nevertheless, Celia wore scarcely more trimmings; and it was only to close observers (2) that her dress differed sister’s, and had a shade of coquetry in its arrangements; for Miss
# Middlemarch: (3790, 4011) elder poets,--in a paragraph of to-day's newspaper usually spoken of as being remarkably clever, but with the addition that her sister Celia had more common-sense. Nevertheless, Celia wore scarcely more trimmings; and it was only to close observers that her dress differed sister's, and had a shade of coquetry in its arrangements; for Miss
# match:  Match(a=1164, b=360, size=4)
#
#
# match 2:
# test9: (14028, 14075) close observers (2) that her dress differed from her sister shade of coquetry in its arrangements; for Miss Brooke’s plain dress- ing was due
# Middlemarch: (4041, 4088) close observers that her dress differed from her sister's shade of coquetry in its arrangements; for Miss Brooke's plain dressing was due to mixed
# match:  Match(a=1172, b=367, size=30)
#
#
# match 3:
# test9: (14106, 14474) Miss Brooke’s plain dress- ing due to mixed conditions, in most of which her sister shared. The pride of being ladies had something to do with it: the Brooke connections, though not exactly aristocratic, were unquestionably (3) ‘good’: if you (4) inquired backward for a generation or two, you would not find any yard-measuring or parcel-tying forefathers—anything lower than an admiral or clergyman Young women of such birth, living in a quiet
# Middlemarch: (4117, 4481) arrangements; for Miss Brooke's plain dressing due to mixed conditions, in most of which her sister shared. The pride of being ladies had something to do with it: the Brooke connections, though not exactly aristocratic, were unquestionably "good:" if you inquired backward for a generation or two, you would not find any yard-measuring or parcel-tying forefathers--anything lower than an admiral or a clergyman even an ancestor discernible as a Puritan gentleman
# match:  Match(a=1202, b=414, size=12)
#
#
# match 4:
# test9: (14482, 14586) forefathers—anything lower than an admiral or clergyman Young women of such birth, living in a quiet country-house, and attending a village church hardly larger parlour, naturally (5) regarded frippery as the ambition
# Middlemarch: (4703, 4807) troubles as the proprietor of a respectable family estate Young women of such birth, living in a quiet country-house, and attending a village church hardly larger parlor, naturally regarded frippery as the ambition
# match:  Match(a=1215, b=427, size=4)
#
#
# match 5:
# test9: (14603, 14650) village church hardly larger than a parlour naturally (5) regarded frippery as the ambition huckster’s daughter. Then there was well-bred economy
# Middlemarch: (4823, 4866) village church hardly larger than a parlor naturally regarded frippery as the ambition huckster's daughter. Then there was well-bred economy
# match:  Match(a=1220, b=432, size=16)
#
#
# match 6:
# test9: (14667, 14856) naturally (5) regarded frippery as the ambition of a huckster daughter. Then there was well-bred economy, which in those days (6) made show in dress the first item to be deducted from, when any margin was required for expenses more distinctive of rank Dorothea’s] mind was theoretic, and yearned by its nature
# Middlemarch: (4883, 5069) naturally regarded frippery as the ambition of a huckster's daughter. Then there was well-bred economy, which in those days made show in dress the first item to be deducted from, when any margin was required for expenses more distinctive of rank reasons would have been enough to account for plain
# match:  Match(a=1237, b=515, size=14)
#
#
# match 7:
# test9: (14877, 15044) required for expenses more distinctive of rank. . . . [Dorothea mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton (7) and her own rule of conduct Certainly such elements in the character of a marriageable girl
# Middlemarch: (5809, 5972) interest in gimp and artificial protrusions of drapery mind was theoretic, and yearned by its nature after some lofty conception of the world which might frankly include the parish of Tipton and her own rule of conduct enamoured of intensity and greatness, and rash in embracing
# match:  Match(a=1251, b=546, size=18)
#
#
# match 8:
# test9: (15058, 15264) include the parish of Tipton (7) and her own rule of conduct Certainly such elements in the character of a marriageable girl tended to interfere with her lot, and hinder it from being decided according to custom (8), by good looks, vanity, and merely canine affection hardly a year since [Dorothea and Celia
# Middlemarch: (6224, 6426) retractations, and then to incur martyrdom after all in a quarter where she had not sought Certainly such elements in the character of a marriageable girl tended to interfere with her lot, and hinder it from being decided according to custom, by good looks, vanity, and merely canine affection elder of the sisters, was not yet twenty, and they had both been educated
# match:  Match(a=1269, b=594, size=3)
#
#
# match 9:
# test9: (15279, 15298) looks, vanity, and merely canine affection hardly a year since Dorothea and Celia] had come to live at Tipton
# Middlemarch: (6827, 6846) way to remedy the disadvantages of their orphaned condition hardly a year since come to live at Tipton Grange with their uncle
# match:  Match(a=1274, b=597, size=25)
#
#
# match 10:
# test9: (15324, 15593) hardly a year since [Dorothea and Celia come to live at Tipton Grange with their uncle, a man nearly sixty, of acquiescent temper, miscellaneous opinions, and uncertain vote. He had travelled in his younger years, and was held in this part of the county (9) to have contracted a too rambling habit of mind. Mr Brooke’s conclusions were as difficult to predict (10) as the weather
# Middlemarch: (6856, 7123) orphaned condition. It was hardly a year since come to live at Tipton Grange with their uncle, a man nearly sixty, of acquiescent temper, miscellaneous opinions, and uncertain vote. He had travelled in his younger years, and was held in this part of the county to have contracted a too rambling habit of mind. Mr Brooke's conclusions were as difficult to predict as the weather
# match:  Match(a=1300, b=623, size=16)
#
#
# match 11:
# test9: (15603, 15803) rambling habit of mind. Mr Brooke conclusions were as difficult to predict (10) as the weather: it was only safe to say (11) that he would act with benevolent intentions, and that he would spend as little money as possible in carrying Dorothea] was regarded as (12) an heiress, for not only had the sisters seven
# Middlemarch: (7134, 7324) rambling habit of mind. Mr. Brooke's conclusions were as difficult to predict as the weather: it was only safe to say that he would act with benevolent intentions, and that he would spend as little money as possible in carrying glutinously indefinite minds enclose some hard
# match:  Match(a=1317, b=691, size=14)
#
#
# match 12:
# test9: (15835, 16003) little money as possible in carrying them out. . . . [Dorothea regarded as (12) an heiress, for not only had the sisters seven hundred a year each from their parents, but if Dorothea married and had a son, that son would inherit Mr Brooke’s estate, presumably worth about three
# Middlemarch: (7962, 8125) age and have some command of money for generous schemes regarded as an heiress; for not only had the sisters seven hundred a-year each from their parents, but if Dorothea married and had a son, that son would inherit Mr Brooke's estate, presumably worth about three
# match:  Match(a=1332, b=706, size=11)
#
#
# match 13:
# test9: (16013, 16117) son would inherit Mr Brooke estate, presumably worth about three thousand a year—a rental which seemed wealth to provincial families Dorothea not marry?—a girl so handsome and with such prospects
# Middlemarch: (8136, 8241) son would inherit Mr. Brooke's estate, presumably worth about three thousand a-year--a rental which seemed wealth to provincial families still discussing Mr. Peel's late
# match:  Match(a=1343, b=736, size=28)
#
#
# match 14:
# test9: (16146, 16450) rental which seemed wealth to provincial families Dorothea not marry?—a girl so handsome and with such prospects? (14) Nothing could hinder it but her love of extremes, and her insistence on regulating life according to notions which might cause a wary man (15) to hesitate before he made her an offer, or even might lead her at last to refuse all offers man would naturally (16) think twice
# Middlemarch: (8450, 8746) nobly exalted the necessities of genteel life Dorothea not marry?--a girl so handsome and with such prospects? Nothing could hinder it but her love of extremes, and her insistence on regulating life according to notions which might cause a wary man to hesitate before he made her an offer, or even might lead her at last to refuse all offers young lady of some birth and fortune, who knelt
# match:  Match(a=1371, b=808, size=20)
#
#
# match 15:
# test9: (16460, 16695) might lead her at last to refuse all offers man would naturally (16) think twice before he risked himself in such fellowship. Women were expected (17) to have weak opinions; but the great safeguard of society and of domestic life was, that opinions were not acted on. Sane people neighbours did (19), so that if any lunatics (20) were at large, one (21) might
# Middlemarch: (9229, 9456) political economy and the keeping of saddle-horses man would naturally think twice before he risked himself in such fellowship. Women were expected to have weak opinions; but the great safeguard of society and of domestic life was, that opinions were not acted on. Sane people neighbors did, so that if any lunatics were at large, one might
# match:  Match(a=1392, b=829, size=14)
#
#
# match 16:
# test9: (16752, 16887) opinions were not acted on. Sane people did (18) what their neighbours lunatics (20) were at large, one (21) might know and avoid them. The rural opinion about the new young ladies, even among the cottagers gener- ally in favour of Celia, as being so amiable
# Middlemarch: (9502, 9628) opinions were not acted on. Sane people did what their neighbors lunatics were at large, one might know and avoid them. The rural opinion about the new young ladies, even among the cottagers generally in favor of Celia, as being so amiable and innocent
# match:  Match(a=1409, b=845, size=5)
#
#
# match 17:
# test9: (16923, 16982) among the cottagers (22), was gener- ally in favour Celia, as being so amiable and innocent-looking, while Miss Brooke’s large eyes seemed, like
# Middlemarch: (9656, 9715) even among the cottagers, was generally in favor Celia, as being so amiable and innocent-looking, while Miss Brooke's large eyes seemed, like
# match:  Match(a=1415, b=851, size=7)
#
#
# match 18:
# test9: (16992, 17054) amiable and innocent-looking, while Miss Brooke large eyes seemed, like her religion, too unusual and striking Yet those who (23) approached 432 Alan Palmer Dorothea
# Middlemarch: (9725, 9787) amiable and innocent-looking, while Miss Brooke's large eyes seemed, like her religion, too unusual and striking Poor Dorothea! compared with her, the innocent-looking
# match:  Match(a=1426, b=880, size=13)
#
#
# match 19:
# test9: (17110, 17307) striking. . . . Yet those who (23) approached 432 Alan Palmer Dorothea, though prejudiced against her by this alarming hearsay (24) , found that she had a charm unaccountably reconcilable with it. Most men (25) thought her bewitching when she was on horseback peculiarities of Dorothea’s character caused Mr
# Middlemarch: (10016, 10203) blazonry or clock-face for it. Yet those who approached Dorothea, though prejudiced against her by this alarming hearsay, found that she had a charm unaccountably reconcilable with it. Most men thought her bewitching when she was on horseback loved the fresh air and the various aspects
# match:  Match(a=1441, b=1033, size=5)
#
#
# match 20:
# test9: (17349, 17401) thought her bewitching when she was on horseback. . . . These peculiarities of Dorothea character caused Mr Brooke to be all the more blamed neighbouring families (26) for not securing some middle-aged
# Middlemarch: (11867, 11920) even Hebrew, if you wished it. These peculiarities of Dorothea's character caused Mr. Brooke to be all the more blamed neighboring families for not securing some middle-aged
# match:  Match(a=1447, b=1039, size=6)
#
#
# match 21:
# test9: (17418, 17479) caused Mr Brooke to be all the more blamed in neighbouring families (26) for not securing some middle-aged lady as guide com- panion to his nieces. But he himself dreaded so much
# Middlemarch: (11936, 11992) caused Mr. Brooke to be all the more blamed in neighboring families for not securing some middle-aged lady as guide companion to his nieces. But he himself dreaded so much the sort
# match:  Match(a=1455, b=1046, size=11)
#
#
# match 22:
# test9: (17503, 17652) aged lady as guide and com- panion nieces. But he himself dreaded so much the sort of superior woman likely to be available for such a position, that he allowed himself to be dissuaded Dorothea’s objections, and was in this case brave enough
# Middlemarch: (12014, 12164) middle-aged lady as guide and companion nieces. But he himself dreaded so much the sort of superior woman likely to be available for such a position, that he allowed himself to be dissuaded Dorothea's objections, and was in this case brave enough
# match:  Match(a=1467, b=1058, size=9)
#
#
# match 23:
# test9: (17667, 17762) available for such a position, that he allowed himself to be dissuaded by Dorothea objections, and was in this case brave enough to defy the world—that is to say, Mrs Cadwallader Rector’s wife, and the small group of gentry
# Middlemarch: (12179, 12276) available for such a position, that he allowed himself to be dissuaded by Dorothea's objections, and was in this case brave enough to defy the world--that is to say, Mrs. Cadwallader Rector's wife, and the small group of gentry
# match:  Match(a=1477, b=1068, size=5)
#
#
# match 24:
# test9: (17776, 17832) world—that is to say, Mrs Cadwallader the Rector wife, and the small group of gentry with whom he visited north-east corner of Loamshire. (27) So Miss
# Middlemarch: (12290, 12346) world--that is to say, Mrs. Cadwallader the Rector's wife, and the small group of gentry with whom he visited northeast corner of Loamshire. So Miss Brooke
# match:  Match(a=1484, b=1074, size=5)
#
#
# match 25:
# test9: (17851, 17900) group of gentry with whom he visited in the north-east corner of Loamshire. (27) So Miss Brooke presided uncle’s household, and did not at all dislike her new authority
# Middlemarch: (12364, 12409) small group of gentry with whom he visited in the northeast corner of Loamshire. So Miss Brooke presided uncle's household, and did not at all dislike her new authority
# match:  Match(a=1490, b=1080, size=6)
#
#
# match 26:
# test9: (17916, 18002) Loamshire. (27) So Miss Brooke presided in her uncle household, and did not at all dislike her new authority, with the homage that belonged would guess that this passage would strike
# Middlemarch: (12425, 12511) Loamshire. So Miss Brooke presided in her uncle's household, and did not at all dislike her new authority, with the homage that belonged Sir James Chettam was going to dine
# match:  Match(a=2700, b=27684, size=7)
#
#
# match 27:
# test9: (33013, 33102) cheated with that quotation. The actual words in the text Middlemarch, in fact, counted on swallowing Lydgate and assimilating him very comfortably understand very easily what that sentence means when we encounter
# Middlemarch: (321957, 322046) knowledge as to the way in which life had been shaping him for that instrumentality Middlemarch, in fact, counted on swallowing Lydgate and assimilating him very comfortably CHAPTER XVI. "All that in woman is adored In thy
# (27,
#  [(13769, 13998),
#   (14028, 14075),
#   (14106, 14474),
#   (14482, 14586),
#   (14603, 14650),
#   (14667, 14856),
#   (14877, 15044),
#   (15058, 15264),
#   (15279, 15298),
#   (15324, 15593),
#   (15603, 15803),
#   (15835, 16003),
#   (16013, 16117),
#   (16146, 16450),
#   (16460, 16695),
#   (16752, 16887),
#   (16923, 16982),
#   (16992, 17054),
#   (17110, 17307),
#   (17349, 17401),
#   (17418, 17479),
#   (17503, 17652),
#   (17667, 17762),
#   (17776, 17832),
#   (17851, 17900),
#   (17916, 18002),
#   (33013, 33102)],
#  [(3790, 4011),
#   (4041, 4088),
#   (4117, 4481),
#   (4703, 4807),
#   (4823, 4866),
#   (4883, 5069),
#   (5809, 5972),
#   (6224, 6426),
#   (6827, 6846),
#   (6856, 7123),
#   (7134, 7324),
#   (7962, 8125),
#   (8136, 8241),
#   (8450, 8746),
#   (9229, 9456),
#   (9502, 9628),
#   (9656, 9715),
#   (9725, 9787),
#   (10016, 10203),
#   (11867, 11920),
#   (11936, 11992),
#   (12014, 12164),
#   (12179, 12276),
#   (12290, 12346),
#   (12364, 12409),
#   (12425, 12511),
#   (321957, 322046)])
